# %% [markdown]
# ## FD_abs[hhb2] ANN Fitting

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
import pickle
from tqdm import tqdm
! pip install pmcx
from concurrent.futures import ThreadPoolExecutor
#from FDNIRS_dprocesser import load_and_process_all as lapa
from sklearn.preprocessing import StandardScaler
# Out:
# Collecting pmcx
#   Downloading pmcx-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 128.7 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.5.2

# %% [markdown]
# ### Read Simulation data

# %%
# -*- coding: utf-8 -*-
# Train an ANN to predict HHB2 from MCX simulation pickles.

import os, re, pickle, math, random
from pathlib import Path
from typing import Any, Iterable

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_FDnirsANN_model(input_dim=192,
                           optimizer=None,
                           loss='mse',
                           metrics=None):
    """
    Constructs and returns the deep MLP regression model.

    Args:
      input_dim (int): size of the input feature vector
      optimizer (str or keras Optimizer): optimizer to use (default: Adam)
      loss (str): loss function (default: 'mse')
      metrics (list): list of metric names (default: ['mae'])

    Returns:
      model: a compiled keras Model instance
    """
    if optimizer is None:
        optimizer = Adam()
    if metrics is None:
        metrics = ['mae']

    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(1000, activation='relu'),
        Dropout(0.1),

        Dense(4096, activation='relu'),
        Dropout(0.1),

        Dense(4096, activation='relu'),
        Dropout(0.2),

        Dense(8192, activation='relu'),
        Dropout(0.2),

        Dense(8192 * 2, activation='relu'),
        Dropout(0.2),

        Dense(8192, activation='relu'),
        Dropout(0.2),

        Dense(4096, activation='relu'),
        Dropout(0.2),

        Dense(2048, activation='relu'),
        Dropout(0.2),

        Dense(1024, activation='relu'),
        Dropout(0.2),

        Dense(512, activation='relu'),
        Dropout(0.1),

        Dense(256, activation='relu'),
        Dropout(0.1),

        Dense(64, activation='relu'),
        Dropout(0.1),

        Dense(32, activation='relu'),
        Dropout(0.0),

        Dense(1)
    ])

    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
# -*- coding: utf-8 -*-
# Train an ANN to predict HHB2 from MCX simulation pickles (dict {10:[100], 30:[100]}).
# Z-SCORES BOTH X and y using TRAIN-ONLY statistics. Shows a tqdm progress bar while loading.

from pathlib import Path
import os, math, random, pickle
from typing import Any, Tuple

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam

from tqdm.auto import tqdm
from concurrent.futures import ThreadPoolExecutor

# ---------------------
# Paths / Config
# ---------------------
RESULT_ROOT = Path('/content/drive/MyDrive/MCX_data/result_folder/cw_stage1')   # part1..part20
GT_CSV      = Path('/content/drive/MyDrive/MCX_data/cw_stage1_csv/satge1.csv')  # columns "ID", "HHB2"
# If your CSV file is actually "stage1.csv", fix the path above.

TARGET_COL  = 'CCO2'     # ground truth column
ID_COL      = 'ID'
EACH_LEN    = 101        # length for key=10 and key=30 individually
TARGET_LEN  = 4 * EACH_LEN  # 200 features total after concatenation
TEST_SIZE   = 0.05
VAL_SIZE    = 0.05
SEED        = 1337

BATCH_SIZE  = 32
EPOCHS      = 200
LR          = 1e-4
BEST_MODEL  = 'best_ann_hhb2.h5'

# Data-loading performance
USE_THREADS = True                 # set False for simple sequential load
NUM_WORKERS = min(32, (os.cpu_count() or 8) * 2)

# ---------------------
# Repro & GPU mem growth
# ---------------------
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# ---------------------
# Helpers
# ---------------------
def _as_float1d(x, want_len):
    """Ensure 1D float32; if length mismatches, resample to want_len."""
    a = np.asarray(x, dtype=np.float32).ravel()
    if a.size == want_len:
        return a
    xp = np.linspace(0.0, 1.0, max(1, a.size), dtype=np.float32)
    xnew = np.linspace(0.0, 1.0, want_len, dtype=np.float32)
    return np.interp(xnew, xp, a).astype(np.float32)

def load_pickle_feature(pkl_path: Path, each_len: int = EACH_LEN) -> np.ndarray:
    """
    Each pickle is a dict with keys 10 and 30, each a list/array length ~ each_len.
    Return a 200-D vector: [values_for_key_10 (each_len), values_for_key_30 (each_len)].
    """
    with open(pkl_path, 'rb') as f:
        obj = pickle.load(f)

    def get_key(d, k):
        if k in d: return d[k]
        sk = str(k)
        if sk in d: return d[sk]
        raise KeyError(f"Missing key {k} (/'{sk}') in {pkl_path}")

    v10 = _as_float1d(get_key(obj, 10), each_len)
    v20 = _as_float1d(get_key(obj, 20), each_len)
    v30 = _as_float1d(get_key(obj, 30), each_len)
    v40 = _as_float1d(get_key(obj, 40), each_len)
    feat = np.concatenate([v10, v20, v30, v40], axis=0).astype(np.float32)
    #if feat.size != 2 * each_len:
    #    raise ValueError(f"{pkl_path}: got {feat.size}, expected {2*each_len}")
    return feat

# ---------------------
# Read GT and build ID -> target mapping
# ---------------------
if not GT_CSV.exists():
    raise FileNotFoundError(f"GT CSV not found: {GT_CSV}")

gt_df = pd.read_csv(GT_CSV)
cols_lc = {c.lower(): c for c in gt_df.columns}
if ID_COL.lower() not in cols_lc or TARGET_COL.lower() not in cols_lc:
    raise ValueError(f"CSV must contain '{ID_COL}' and '{TARGET_COL}'. Found: {list(gt_df.columns)}")
ID_COL_REAL = cols_lc[ID_COL.lower()]
TARGET_COL_REAL = cols_lc[TARGET_COL.lower()]

id_to_target = dict(zip(gt_df[ID_COL_REAL].astype(int).tolist(),
                        gt_df[TARGET_COL_REAL].astype(float).tolist()))

# ---------------------
# Scan all folders and gather matching (ID, path)
# ---------------------
if not RESULT_ROOT.exists():
    raise FileNotFoundError(f"RESULT_ROOT not found: {RESULT_ROOT}")

pairs: list[Tuple[int, Path]] = []
for sub in sorted(RESULT_ROOT.glob('part*')):
    if not sub.is_dir():
        continue
    for p in sorted(sub.glob('*.pkl')):
        try:
            pid = int(Path(p).stem)  # expects filenames like "123.pkl"
        except Exception:
            continue
        if pid in id_to_target:
            pairs.append((pid, p))

if not pairs:
    raise RuntimeError("No matching (ID, pickle) pairs found. Check folders/filenames.")

print(f"Found {len(pairs)} matching pickles with GT.")

# ---------------------
# Build dataset X, y with progress bar (threaded or sequential)
# ---------------------
N = len(pairs)
X = np.empty((N, TARGET_LEN), dtype=np.float32)
y = np.empty(N, dtype=np.float32)
kept_ids = np.empty(N, dtype=np.int64)

if USE_THREADS:
    def _worker(args):
        i, (pid, p) = args
        feat = load_pickle_feature(p, EACH_LEN)
        if feat.size != TARGET_LEN:
            raise ValueError(f"{p}: feature length {feat.size} != {TARGET_LEN}")
        return i, pid, feat

    with ThreadPoolExecutor(max_workers=NUM_WORKERS) as ex:
        for i, pid, feat in tqdm(ex.map(_worker, enumerate(pairs)), total=N,
                                 desc="Loading (threads)", unit="file"):
            X[i] = feat
            y[i] = float(id_to_target[pid])
            kept_ids[i] = int(pid)
else:
    for i, (pid, p) in tqdm(enumerate(pairs), total=N,
                            desc="Loading (sequential)", unit="file"):
        feat = load_pickle_feature(p, EACH_LEN)
        if feat.size != TARGET_LEN:
            raise ValueError(f"{p}: feature length {feat.size} != {TARGET_LEN}")
        X[i] = feat
        y[i] = float(id_to_target[pid])
        kept_ids[i] = int(pid)

# ---------------------
# Split 80/10/10
# ---------------------
X_trainval, X_test, y_trainval, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=SEED
)
val_frac_of_trainval = VAL_SIZE / (1.0 - TEST_SIZE)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=val_frac_of_trainval, random_state=SEED
)

print(f"Split sizes → train: {len(y_train)}, val: {len(y_val)}, test: {len(y_test)}")

# ---------------------
# Z-score normalization for BOTH X and y (TRAIN-ONLY STATS)
# ---------------------
x_mean = X_train.mean(axis=0, keepdims=True)
x_std  = X_train.std(axis=0, keepdims=True) + 1e-8

# apply z-score to x
def zscore_X(a): return (a - x_mean) / x_std

X_train_n = zscore_X(X_train).astype(np.float32)
X_val_n   = zscore_X(X_val).astype(np.float32)
X_test_n  = zscore_X(X_test).astype(np.float32)

# apply z-score to y
y_mean = float(y_train.mean())
y_std  = float(y_train.std() + 1e-8)

def zscore_y(a): return (a - y_mean) / y_std
def inv_zscore_y(a_n): return a_n * y_std + y_mean

y_train_n = zscore_y(y_train).astype(np.float32)
y_val_n   = zscore_y(y_val).astype(np.float32)

print("Applied z-score on X and y using TRAIN-only statistics.")
print(f"  X: mean shape {x_mean.shape}, std shape {x_std.shape}")
print(f"  y: mean {y_mean:.6f}, std {y_std:.6f}")

# ---------------------
# Train
# ---------------------
model = build_FDnirsANN_model(
    input_dim=TARGET_LEN,
    optimizer=Adam(learning_rate=LR),
    loss='mse',
    metrics=['mae']
)

callbacks = [
    keras.callbacks.ModelCheckpoint(BEST_MODEL, monitor='val_mae', mode='min',
                                    save_best_only=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=10,
                                      min_lr=1e-6, verbose=1),
]

history = model.fit(
    X_train_n, y_train_n,
    validation_data=(X_val_n, y_val_n),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1,
)

# Save best (ensure BEST_MODEL exists even if ES restored weights)
model.save(BEST_MODEL)

# ---------------------
# Load BEST and evaluate
# ---------------------
best = keras.models.load_model(BEST_MODEL, compile=False)

pred_test_n = best.predict(X_test_n, verbose=0).ravel().astype(np.float64)
pred_test   = inv_zscore_y(pred_test_n)

mae  = mean_absolute_error(y_test, pred_test)
rmse = math.sqrt(mean_squared_error(y_test, pred_test))
r2   = r2_score(y_test, pred_test)

print("\n=== TEST METRICS (best checkpoint; de-normalized ŷ) ===")
print(f"MAE : {mae:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"R^2 : {r2:.6f}")
print(f"Saved best model → {BEST_MODEL}")

# ---------------------
# Plot GT vs Pred with identity & best-fit line + MSE/MARE (original units)
# ---------------------
mse  = mean_squared_error(y_test, pred_test)
mare = np.mean(np.abs((pred_test - y_test) / np.clip(np.abs(y_test), 1e-8, None))) * 100.0

plt.figure(figsize=(5, 4.5), dpi=160)
plt.scatter(y_test, pred_test, s=14, alpha=0.6, edgecolors='none')

lo = float(min(np.min(y_test), np.min(pred_test)))
hi = float(max(np.max(y_test), np.max(pred_test)))
if not np.isfinite(lo) or not np.isfinite(hi) or lo == hi:
    lo, hi = -1.0, 1.0

plt.plot([lo, hi], [lo, hi], 'k--', lw=1.2, alpha=0.8, label='y = x')

if np.std(y_test) > 0:
    a, b = np.polyfit(y_test, pred_test, 1)
    xx = np.linspace(lo, hi, 200)
    plt.plot(xx, a * xx + b, lw=2, label=f'y = {a:.3f}x + {b:.3f}')

plt.xlabel("GT HHB2")
plt.ylabel("Predicted HHB2")
plt.title(f"Test: R² = {r2:.3f}, MAE = {mae:.3f}, RMSE = {rmse:.3f}")

txt = f"MSE = {mse:.2e}\nMARE = {mare:.2f}%"
plt.text(0.02, 0.98, txt,
         transform=plt.gca().transAxes, va='top', ha='left',
         color='#9c2a2a', fontsize=11, fontweight='bold')

plt.legend(loc='lower right', frameon=False)
plt.tight_layout()
plt.show()
# Out:
# Found 3206 matching pickles with GT.
# Loading (threads):   0%|          | 0/3206 [00:00<?, ?file/s]
# Split sizes → train: 2884, val: 161, test: 161
# Applied z-score on X and y using TRAIN-only statistics.
#   X: mean shape (1, 404), std shape (1, 404)
#   y: mean 7.494852, std 4.339008
# Epoch 1/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 1.0406 - mae: 0.8860
# Epoch 1: val_mae improved from inf to 0.86494, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 60s 538ms/step - loss: 1.0404 - mae: 0.8858 - val_loss: 0.9911 - val_mae: 0.8649 - learning_rate: 1.0000e-04
# Epoch 2/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.0138 - mae: 0.8780
# Epoch 2: val_mae improved from 0.86494 to 0.86000, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 17s 193ms/step - loss: 1.0136 - mae: 0.8778 - val_loss: 0.9825 - val_mae: 0.8600 - learning_rate: 1.0000e-04
# Epoch 3/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.0115 - mae: 0.8752
# Epoch 3: val_mae did not improve from 0.86000
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 1.0114 - mae: 0.8751 - val_loss: 0.9811 - val_mae: 0.8608 - learning_rate: 1.0000e-04
# Epoch 4/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.0020 - mae: 0.8721
# Epoch 4: val_mae improved from 0.86000 to 0.83856, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 20s 220ms/step - loss: 1.0018 - mae: 0.8720 - val_loss: 0.9601 - val_mae: 0.8386 - learning_rate: 1.0000e-04
# Epoch 5/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.0008 - mae: 0.8604
# Epoch 5: val_mae improved from 0.83856 to 0.81095, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 51s 567ms/step - loss: 1.0005 - mae: 0.8603 - val_loss: 0.9002 - val_mae: 0.8110 - learning_rate: 1.0000e-04
# Epoch 6/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.9645 - mae: 0.8441
# Epoch 6: val_mae did not improve from 0.81095
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.9641 - mae: 0.8439 - val_loss: 0.9571 - val_mae: 0.8467 - learning_rate: 1.0000e-04
# Epoch 7/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.9500 - mae: 0.8417
# Epoch 7: val_mae did not improve from 0.81095
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.9495 - mae: 0.8414 - val_loss: 0.8847 - val_mae: 0.8114 - learning_rate: 1.0000e-04
# Epoch 8/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8648 - mae: 0.7884
# Epoch 8: val_mae improved from 0.81095 to 0.77120, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 19s 205ms/step - loss: 0.8646 - mae: 0.7883 - val_loss: 0.8119 - val_mae: 0.7712 - learning_rate: 1.0000e-04
# Epoch 9/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7896 - mae: 0.7453
# Epoch 9: val_mae improved from 0.77120 to 0.70705, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - loss: 0.7893 - mae: 0.7452 - val_loss: 0.7451 - val_mae: 0.7070 - learning_rate: 1.0000e-04
# Epoch 10/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7407 - mae: 0.7119
# Epoch 10: val_mae improved from 0.70705 to 0.69189, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 22s 244ms/step - loss: 0.7405 - mae: 0.7118 - val_loss: 0.7082 - val_mae: 0.6919 - learning_rate: 1.0000e-04
# Epoch 11/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7237 - mae: 0.7051
# Epoch 11: val_mae improved from 0.69189 to 0.65646, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 17s 192ms/step - loss: 0.7236 - mae: 0.7050 - val_loss: 0.6274 - val_mae: 0.6565 - learning_rate: 1.0000e-04
# Epoch 12/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6716 - mae: 0.6748
# Epoch 12: val_mae did not improve from 0.65646
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.6713 - mae: 0.6747 - val_loss: 0.7775 - val_mae: 0.6738 - learning_rate: 1.0000e-04
# Epoch 13/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6568 - mae: 0.6700
# Epoch 13: val_mae did not improve from 0.65646
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.6567 - mae: 0.6700 - val_loss: 0.6643 - val_mae: 0.6763 - learning_rate: 1.0000e-04
# Epoch 14/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6960 - mae: 0.6906
# Epoch 14: val_mae improved from 0.65646 to 0.63008, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - loss: 0.6956 - mae: 0.6905 - val_loss: 0.5930 - val_mae: 0.6301 - learning_rate: 1.0000e-04
# Epoch 15/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6214 - mae: 0.6446
# Epoch 15: val_mae did not improve from 0.63008
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.6213 - mae: 0.6446 - val_loss: 0.6058 - val_mae: 0.6465 - learning_rate: 1.0000e-04
# Epoch 16/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6037 - mae: 0.6358
# Epoch 16: val_mae did not improve from 0.63008
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.6036 - mae: 0.6358 - val_loss: 0.6370 - val_mae: 0.6553 - learning_rate: 1.0000e-04
# Epoch 17/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6007 - mae: 0.6369
# Epoch 17: val_mae improved from 0.63008 to 0.62877, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 23s 258ms/step - loss: 0.6005 - mae: 0.6367 - val_loss: 0.5752 - val_mae: 0.6288 - learning_rate: 1.0000e-04
# Epoch 18/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5819 - mae: 0.6222
# Epoch 18: val_mae did not improve from 0.62877
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5819 - mae: 0.6222 - val_loss: 0.6175 - val_mae: 0.6468 - learning_rate: 1.0000e-04
# Epoch 19/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5839 - mae: 0.6219
# Epoch 19: val_mae improved from 0.62877 to 0.60947, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - loss: 0.5839 - mae: 0.6219 - val_loss: 0.5769 - val_mae: 0.6095 - learning_rate: 1.0000e-04
# Epoch 20/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5649 - mae: 0.6152
# Epoch 20: val_mae did not improve from 0.60947
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5648 - mae: 0.6152 - val_loss: 0.6055 - val_mae: 0.6144 - learning_rate: 1.0000e-04
# Epoch 21/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5539 - mae: 0.6042
# Epoch 21: val_mae improved from 0.60947 to 0.60238, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - loss: 0.5539 - mae: 0.6042 - val_loss: 0.5357 - val_mae: 0.6024 - learning_rate: 1.0000e-04
# Epoch 22/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5451 - mae: 0.6008
# Epoch 22: val_mae did not improve from 0.60238
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5450 - mae: 0.6007 - val_loss: 0.5383 - val_mae: 0.6089 - learning_rate: 1.0000e-04
# Epoch 23/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5321 - mae: 0.5895
# Epoch 23: val_mae improved from 0.60238 to 0.59033, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - loss: 0.5321 - mae: 0.5894 - val_loss: 0.5311 - val_mae: 0.5903 - learning_rate: 1.0000e-04
# Epoch 24/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5384 - mae: 0.5900
# Epoch 24: val_mae improved from 0.59033 to 0.56390, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 23s 257ms/step - loss: 0.5382 - mae: 0.5900 - val_loss: 0.4772 - val_mae: 0.5639 - learning_rate: 1.0000e-04
# Epoch 25/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5085 - mae: 0.5775
# Epoch 25: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5084 - mae: 0.5774 - val_loss: 0.4820 - val_mae: 0.5657 - learning_rate: 1.0000e-04
# Epoch 26/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5084 - mae: 0.5800
# Epoch 26: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5086 - mae: 0.5802 - val_loss: 0.5612 - val_mae: 0.6330 - learning_rate: 1.0000e-04
# Epoch 27/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5105 - mae: 0.5726
# Epoch 27: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5103 - mae: 0.5725 - val_loss: 0.5349 - val_mae: 0.5938 - learning_rate: 1.0000e-04
# Epoch 28/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4802 - mae: 0.5619
# Epoch 28: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4801 - mae: 0.5618 - val_loss: 0.4893 - val_mae: 0.5759 - learning_rate: 1.0000e-04
# Epoch 29/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4982 - mae: 0.5701
# Epoch 29: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4979 - mae: 0.5700 - val_loss: 0.4734 - val_mae: 0.5684 - learning_rate: 1.0000e-04
# Epoch 30/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5111 - mae: 0.5837
# Epoch 30: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5109 - mae: 0.5835 - val_loss: 0.5280 - val_mae: 0.5947 - learning_rate: 1.0000e-04
# Epoch 31/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4929 - mae: 0.5639
# Epoch 31: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4929 - mae: 0.5639 - val_loss: 0.5264 - val_mae: 0.5922 - learning_rate: 1.0000e-04
# Epoch 32/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4941 - mae: 0.5679
# Epoch 32: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4939 - mae: 0.5678 - val_loss: 0.5954 - val_mae: 0.5981 - learning_rate: 1.0000e-04
# Epoch 33/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5301 - mae: 0.5791
# Epoch 33: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5298 - mae: 0.5791 - val_loss: 0.5692 - val_mae: 0.6132 - learning_rate: 1.0000e-04
# Epoch 34/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.5223 - mae: 0.5805
# Epoch 34: val_mae did not improve from 0.56390
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.5221 - mae: 0.5804 - val_loss: 0.5517 - val_mae: 0.5971 - learning_rate: 1.0000e-04
# Epoch 35/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4636 - mae: 0.5468
# Epoch 35: val_mae did not improve from 0.56390
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4634 - mae: 0.5467 - val_loss: 0.4949 - val_mae: 0.5758 - learning_rate: 5.0000e-05
# Epoch 36/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4287 - mae: 0.5293
# Epoch 36: val_mae improved from 0.56390 to 0.55481, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - loss: 0.4286 - mae: 0.5293 - val_loss: 0.4770 - val_mae: 0.5548 - learning_rate: 5.0000e-05
# Epoch 37/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4171 - mae: 0.5188
# Epoch 37: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.4171 - mae: 0.5188 - val_loss: 0.5328 - val_mae: 0.5931 - learning_rate: 5.0000e-05
# Epoch 38/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4381 - mae: 0.5312
# Epoch 38: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.4380 - mae: 0.5311 - val_loss: 0.4962 - val_mae: 0.5742 - learning_rate: 5.0000e-05
# Epoch 39/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4156 - mae: 0.5226
# Epoch 39: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.4154 - mae: 0.5225 - val_loss: 0.4876 - val_mae: 0.5614 - learning_rate: 5.0000e-05
# Epoch 40/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4250 - mae: 0.5235
# Epoch 40: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4249 - mae: 0.5234 - val_loss: 0.5042 - val_mae: 0.5840 - learning_rate: 5.0000e-05
# Epoch 41/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4030 - mae: 0.5120
# Epoch 41: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4029 - mae: 0.5119 - val_loss: 0.4868 - val_mae: 0.5673 - learning_rate: 5.0000e-05
# Epoch 42/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4061 - mae: 0.5064
# Epoch 42: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4059 - mae: 0.5063 - val_loss: 0.4774 - val_mae: 0.5610 - learning_rate: 5.0000e-05
# Epoch 43/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3941 - mae: 0.5021
# Epoch 43: val_mae did not improve from 0.55481
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3939 - mae: 0.5020 - val_loss: 0.4873 - val_mae: 0.5668 - learning_rate: 5.0000e-05
# Epoch 44/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4082 - mae: 0.5093
# Epoch 44: val_mae improved from 0.55481 to 0.54153, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - loss: 0.4080 - mae: 0.5091 - val_loss: 0.4513 - val_mae: 0.5415 - learning_rate: 5.0000e-05
# Epoch 45/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3891 - mae: 0.5020
# Epoch 45: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3890 - mae: 0.5019 - val_loss: 0.4684 - val_mae: 0.5606 - learning_rate: 5.0000e-05
# Epoch 46/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3762 - mae: 0.4917
# Epoch 46: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3762 - mae: 0.4916 - val_loss: 0.4780 - val_mae: 0.5603 - learning_rate: 5.0000e-05
# Epoch 47/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3881 - mae: 0.5009
# Epoch 47: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3880 - mae: 0.5008 - val_loss: 0.4703 - val_mae: 0.5596 - learning_rate: 5.0000e-05
# Epoch 48/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3980 - mae: 0.5083
# Epoch 48: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3977 - mae: 0.5081 - val_loss: 0.4523 - val_mae: 0.5476 - learning_rate: 5.0000e-05
# Epoch 49/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3956 - mae: 0.5073
# Epoch 49: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3955 - mae: 0.5072 - val_loss: 0.4674 - val_mae: 0.5534 - learning_rate: 5.0000e-05
# Epoch 50/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3890 - mae: 0.4975
# Epoch 50: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3888 - mae: 0.4974 - val_loss: 0.5169 - val_mae: 0.5718 - learning_rate: 5.0000e-05
# Epoch 51/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.4064 - mae: 0.5032
# Epoch 51: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.4062 - mae: 0.5031 - val_loss: 0.4630 - val_mae: 0.5519 - learning_rate: 5.0000e-05
# Epoch 52/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3857 - mae: 0.4940
# Epoch 52: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3855 - mae: 0.4938 - val_loss: 0.4746 - val_mae: 0.5577 - learning_rate: 5.0000e-05
# Epoch 53/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3749 - mae: 0.4864
# Epoch 53: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3747 - mae: 0.4863 - val_loss: 0.5130 - val_mae: 0.5736 - learning_rate: 5.0000e-05
# Epoch 54/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3865 - mae: 0.4964
# Epoch 54: val_mae did not improve from 0.54153
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3863 - mae: 0.4962 - val_loss: 0.4803 - val_mae: 0.5549 - learning_rate: 5.0000e-05
# Epoch 55/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3654 - mae: 0.4801
# Epoch 55: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3652 - mae: 0.4800 - val_loss: 0.4754 - val_mae: 0.5480 - learning_rate: 2.5000e-05
# Epoch 56/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3524 - mae: 0.4679
# Epoch 56: val_mae did not improve from 0.54153
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3522 - mae: 0.4677 - val_loss: 0.4730 - val_mae: 0.5487 - learning_rate: 2.5000e-05
# Epoch 57/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3506 - mae: 0.4652
# Epoch 57: val_mae improved from 0.54153 to 0.53958, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - loss: 0.3504 - mae: 0.4651 - val_loss: 0.4612 - val_mae: 0.5396 - learning_rate: 2.5000e-05
# Epoch 58/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3261 - mae: 0.4542
# Epoch 58: val_mae did not improve from 0.53958
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3260 - mae: 0.4541 - val_loss: 0.4553 - val_mae: 0.5420 - learning_rate: 2.5000e-05
# Epoch 59/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3353 - mae: 0.4540
# Epoch 59: val_mae improved from 0.53958 to 0.53732, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - loss: 0.3352 - mae: 0.4539 - val_loss: 0.4537 - val_mae: 0.5373 - learning_rate: 2.5000e-05
# Epoch 60/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3275 - mae: 0.4582
# Epoch 60: val_mae improved from 0.53732 to 0.53333, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - loss: 0.3274 - mae: 0.4581 - val_loss: 0.4436 - val_mae: 0.5333 - learning_rate: 2.5000e-05
# Epoch 61/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3174 - mae: 0.4467
# Epoch 61: val_mae improved from 0.53333 to 0.52505, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - loss: 0.3173 - mae: 0.4466 - val_loss: 0.4402 - val_mae: 0.5251 - learning_rate: 2.5000e-05
# Epoch 62/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3305 - mae: 0.4495
# Epoch 62: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3304 - mae: 0.4494 - val_loss: 0.4381 - val_mae: 0.5256 - learning_rate: 2.5000e-05
# Epoch 63/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3090 - mae: 0.4374
# Epoch 63: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3090 - mae: 0.4374 - val_loss: 0.4401 - val_mae: 0.5327 - learning_rate: 2.5000e-05
# Epoch 64/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3143 - mae: 0.4389
# Epoch 64: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3142 - mae: 0.4389 - val_loss: 0.4419 - val_mae: 0.5349 - learning_rate: 2.5000e-05
# Epoch 65/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3050 - mae: 0.4375
# Epoch 65: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3049 - mae: 0.4374 - val_loss: 0.4654 - val_mae: 0.5454 - learning_rate: 2.5000e-05
# Epoch 66/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3087 - mae: 0.4337
# Epoch 66: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3086 - mae: 0.4336 - val_loss: 0.4382 - val_mae: 0.5316 - learning_rate: 2.5000e-05
# Epoch 67/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3123 - mae: 0.4379
# Epoch 67: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3122 - mae: 0.4378 - val_loss: 0.4415 - val_mae: 0.5265 - learning_rate: 2.5000e-05
# Epoch 68/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.3035 - mae: 0.4309
# Epoch 68: val_mae did not improve from 0.52505
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.3034 - mae: 0.4309 - val_loss: 0.4450 - val_mae: 0.5449 - learning_rate: 2.5000e-05
# Epoch 69/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2956 - mae: 0.4250
# Epoch 69: val_mae improved from 0.52505 to 0.52083, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 155s 2s/step - loss: 0.2956 - mae: 0.4249 - val_loss: 0.4289 - val_mae: 0.5208 - learning_rate: 2.5000e-05
# Epoch 70/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2882 - mae: 0.4185
# Epoch 70: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2881 - mae: 0.4184 - val_loss: 0.4418 - val_mae: 0.5428 - learning_rate: 2.5000e-05
# Epoch 71/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2929 - mae: 0.4201
# Epoch 71: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2928 - mae: 0.4200 - val_loss: 0.4706 - val_mae: 0.5452 - learning_rate: 2.5000e-05
# Epoch 72/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2886 - mae: 0.4205
# Epoch 72: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2885 - mae: 0.4204 - val_loss: 0.4631 - val_mae: 0.5375 - learning_rate: 2.5000e-05
# Epoch 73/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2935 - mae: 0.4225
# Epoch 73: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2934 - mae: 0.4224 - val_loss: 0.4965 - val_mae: 0.5616 - learning_rate: 2.5000e-05
# Epoch 74/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2910 - mae: 0.4174
# Epoch 74: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2907 - mae: 0.4172 - val_loss: 0.4582 - val_mae: 0.5441 - learning_rate: 2.5000e-05
# Epoch 75/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2917 - mae: 0.4156
# Epoch 75: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2915 - mae: 0.4155 - val_loss: 0.4436 - val_mae: 0.5313 - learning_rate: 2.5000e-05
# Epoch 76/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2690 - mae: 0.4017
# Epoch 76: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2690 - mae: 0.4016 - val_loss: 0.4656 - val_mae: 0.5443 - learning_rate: 2.5000e-05
# Epoch 77/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2779 - mae: 0.4097
# Epoch 77: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2777 - mae: 0.4095 - val_loss: 0.4642 - val_mae: 0.5430 - learning_rate: 2.5000e-05
# Epoch 78/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2749 - mae: 0.4048
# Epoch 78: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2748 - mae: 0.4046 - val_loss: 0.4674 - val_mae: 0.5488 - learning_rate: 2.5000e-05
# Epoch 79/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2656 - mae: 0.3995
# Epoch 79: val_mae did not improve from 0.52083
#
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2655 - mae: 0.3994 - val_loss: 0.5261 - val_mae: 0.5778 - learning_rate: 2.5000e-05
# Epoch 80/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2687 - mae: 0.3956
# Epoch 80: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2685 - mae: 0.3955 - val_loss: 0.4458 - val_mae: 0.5337 - learning_rate: 1.2500e-05
# Epoch 81/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2466 - mae: 0.3784
# Epoch 81: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2465 - mae: 0.3784 - val_loss: 0.4314 - val_mae: 0.5278 - learning_rate: 1.2500e-05
# Epoch 82/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2453 - mae: 0.3798
# Epoch 82: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2453 - mae: 0.3797 - val_loss: 0.4312 - val_mae: 0.5214 - learning_rate: 1.2500e-05
# Epoch 83/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2441 - mae: 0.3838
# Epoch 83: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2440 - mae: 0.3837 - val_loss: 0.4350 - val_mae: 0.5307 - learning_rate: 1.2500e-05
# Epoch 84/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2364 - mae: 0.3778
# Epoch 84: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2364 - mae: 0.3777 - val_loss: 0.4615 - val_mae: 0.5424 - learning_rate: 1.2500e-05
# Epoch 85/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2383 - mae: 0.3764
# Epoch 85: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2382 - mae: 0.3763 - val_loss: 0.4512 - val_mae: 0.5439 - learning_rate: 1.2500e-05
# Epoch 86/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2331 - mae: 0.3746
# Epoch 86: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2330 - mae: 0.3745 - val_loss: 0.4477 - val_mae: 0.5369 - learning_rate: 1.2500e-05
# Epoch 87/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2263 - mae: 0.3655
# Epoch 87: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2262 - mae: 0.3655 - val_loss: 0.4415 - val_mae: 0.5383 - learning_rate: 1.2500e-05
# Epoch 88/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2227 - mae: 0.3616
# Epoch 88: val_mae did not improve from 0.52083
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2227 - mae: 0.3616 - val_loss: 0.4348 - val_mae: 0.5301 - learning_rate: 1.2500e-05
# Epoch 89/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2277 - mae: 0.3638
# Epoch 89: val_mae improved from 0.52083 to 0.51878, saving model to best_ann_hhb2.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 31s 345ms/step - loss: 0.2276 - mae: 0.3638 - val_loss: 0.4236 - val_mae: 0.5188 - learning_rate: 1.2500e-05
# Epoch 90/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2327 - mae: 0.3653
# Epoch 90: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2326 - mae: 0.3652 - val_loss: 0.4435 - val_mae: 0.5293 - learning_rate: 1.2500e-05
# Epoch 91/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2208 - mae: 0.3582
# Epoch 91: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2207 - mae: 0.3581 - val_loss: 0.4519 - val_mae: 0.5396 - learning_rate: 1.2500e-05
# Epoch 92/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2154 - mae: 0.3529
# Epoch 92: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2154 - mae: 0.3529 - val_loss: 0.4587 - val_mae: 0.5400 - learning_rate: 1.2500e-05
# Epoch 93/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2221 - mae: 0.3616
# Epoch 93: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2220 - mae: 0.3615 - val_loss: 0.4454 - val_mae: 0.5381 - learning_rate: 1.2500e-05
# Epoch 94/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2112 - mae: 0.3550
# Epoch 94: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2112 - mae: 0.3549 - val_loss: 0.4568 - val_mae: 0.5372 - learning_rate: 1.2500e-05
# Epoch 95/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2110 - mae: 0.3496
# Epoch 95: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2110 - mae: 0.3495 - val_loss: 0.4560 - val_mae: 0.5377 - learning_rate: 1.2500e-05
# Epoch 96/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2081 - mae: 0.3462
# Epoch 96: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2081 - mae: 0.3462 - val_loss: 0.4556 - val_mae: 0.5406 - learning_rate: 1.2500e-05
# Epoch 97/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2007 - mae: 0.3444
# Epoch 97: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2007 - mae: 0.3443 - val_loss: 0.4618 - val_mae: 0.5415 - learning_rate: 1.2500e-05
# Epoch 98/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2120 - mae: 0.3491
# Epoch 98: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2119 - mae: 0.3491 - val_loss: 0.4522 - val_mae: 0.5431 - learning_rate: 1.2500e-05
# Epoch 99/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2104 - mae: 0.3501
# Epoch 99: val_mae did not improve from 0.51878
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2104 - mae: 0.3500 - val_loss: 0.4638 - val_mae: 0.5478 - learning_rate: 1.2500e-05
# Epoch 100/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2057 - mae: 0.3439
# Epoch 100: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.2056 - mae: 0.3438 - val_loss: 0.4579 - val_mae: 0.5400 - learning_rate: 6.2500e-06
# Epoch 101/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1957 - mae: 0.3361
# Epoch 101: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1955 - mae: 0.3360 - val_loss: 0.4745 - val_mae: 0.5518 - learning_rate: 6.2500e-06
# Epoch 102/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1970 - mae: 0.3355
# Epoch 102: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1969 - mae: 0.3354 - val_loss: 0.4590 - val_mae: 0.5356 - learning_rate: 6.2500e-06
# Epoch 103/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1938 - mae: 0.3338
# Epoch 103: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1937 - mae: 0.3337 - val_loss: 0.4710 - val_mae: 0.5460 - learning_rate: 6.2500e-06
# Epoch 104/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1891 - mae: 0.3311
# Epoch 104: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1890 - mae: 0.3310 - val_loss: 0.4745 - val_mae: 0.5506 - learning_rate: 6.2500e-06
# Epoch 105/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1807 - mae: 0.3280
# Epoch 105: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1806 - mae: 0.3279 - val_loss: 0.4712 - val_mae: 0.5494 - learning_rate: 6.2500e-06
# Epoch 106/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1843 - mae: 0.3214
# Epoch 106: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1843 - mae: 0.3213 - val_loss: 0.4731 - val_mae: 0.5455 - learning_rate: 6.2500e-06
# Epoch 107/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1809 - mae: 0.3236
# Epoch 107: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1809 - mae: 0.3235 - val_loss: 0.4520 - val_mae: 0.5314 - learning_rate: 6.2500e-06
# Epoch 108/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1830 - mae: 0.3198
# Epoch 108: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1829 - mae: 0.3198 - val_loss: 0.4618 - val_mae: 0.5432 - learning_rate: 6.2500e-06
# Epoch 109/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1855 - mae: 0.3270
# Epoch 109: val_mae did not improve from 0.51878
#
# Epoch 109: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1854 - mae: 0.3269 - val_loss: 0.4695 - val_mae: 0.5434 - learning_rate: 6.2500e-06
# Epoch 110/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1825 - mae: 0.3234
# Epoch 110: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1824 - mae: 0.3233 - val_loss: 0.4673 - val_mae: 0.5432 - learning_rate: 3.1250e-06
# Epoch 111/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1748 - mae: 0.3162
# Epoch 111: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1747 - mae: 0.3161 - val_loss: 0.4788 - val_mae: 0.5481 - learning_rate: 3.1250e-06
# Epoch 112/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1768 - mae: 0.3196
# Epoch 112: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1767 - mae: 0.3195 - val_loss: 0.4858 - val_mae: 0.5552 - learning_rate: 3.1250e-06
# Epoch 113/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1722 - mae: 0.3105
# Epoch 113: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1722 - mae: 0.3105 - val_loss: 0.4763 - val_mae: 0.5505 - learning_rate: 3.1250e-06
# Epoch 114/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1780 - mae: 0.3174
# Epoch 114: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1778 - mae: 0.3173 - val_loss: 0.4675 - val_mae: 0.5461 - learning_rate: 3.1250e-06
# Epoch 115/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1770 - mae: 0.3167
# Epoch 115: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1769 - mae: 0.3166 - val_loss: 0.4674 - val_mae: 0.5411 - learning_rate: 3.1250e-06
# Epoch 116/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1773 - mae: 0.3156
# Epoch 116: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1771 - mae: 0.3155 - val_loss: 0.4743 - val_mae: 0.5504 - learning_rate: 3.1250e-06
# Epoch 117/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1735 - mae: 0.3109
# Epoch 117: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1734 - mae: 0.3108 - val_loss: 0.4670 - val_mae: 0.5429 - learning_rate: 3.1250e-06
# Epoch 118/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1760 - mae: 0.3171
# Epoch 118: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1758 - mae: 0.3169 - val_loss: 0.4689 - val_mae: 0.5453 - learning_rate: 3.1250e-06
# Epoch 119/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1664 - mae: 0.3072
# Epoch 119: val_mae did not improve from 0.51878
#
# Epoch 119: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1664 - mae: 0.3072 - val_loss: 0.4746 - val_mae: 0.5471 - learning_rate: 3.1250e-06
# Epoch 120/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.1770 - mae: 0.3192
# Epoch 120: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1768 - mae: 0.3191 - val_loss: 0.4582 - val_mae: 0.5391 - learning_rate: 1.5625e-06
# Epoch 121/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1725 - mae: 0.3126
# Epoch 121: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1724 - mae: 0.3126 - val_loss: 0.4688 - val_mae: 0.5449 - learning_rate: 1.5625e-06
# Epoch 122/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1655 - mae: 0.3082
# Epoch 122: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1655 - mae: 0.3082 - val_loss: 0.4707 - val_mae: 0.5461 - learning_rate: 1.5625e-06
# Epoch 123/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1596 - mae: 0.3052
# Epoch 123: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1595 - mae: 0.3052 - val_loss: 0.4654 - val_mae: 0.5427 - learning_rate: 1.5625e-06
# Epoch 124/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1620 - mae: 0.3060
# Epoch 124: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1620 - mae: 0.3060 - val_loss: 0.4713 - val_mae: 0.5455 - learning_rate: 1.5625e-06
# Epoch 125/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1673 - mae: 0.3079
# Epoch 125: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1672 - mae: 0.3078 - val_loss: 0.4672 - val_mae: 0.5432 - learning_rate: 1.5625e-06
# Epoch 126/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1668 - mae: 0.3117
# Epoch 126: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1667 - mae: 0.3116 - val_loss: 0.4722 - val_mae: 0.5435 - learning_rate: 1.5625e-06
# Epoch 127/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1577 - mae: 0.2983
# Epoch 127: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1576 - mae: 0.2983 - val_loss: 0.4723 - val_mae: 0.5444 - learning_rate: 1.5625e-06
# Epoch 128/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1619 - mae: 0.3012
# Epoch 128: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1618 - mae: 0.3012 - val_loss: 0.4737 - val_mae: 0.5496 - learning_rate: 1.5625e-06
# Epoch 129/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1640 - mae: 0.3057
# Epoch 129: val_mae did not improve from 0.51878
#
# Epoch 129: ReduceLROnPlateau reducing learning rate to 1e-06.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1639 - mae: 0.3057 - val_loss: 0.4747 - val_mae: 0.5474 - learning_rate: 1.5625e-06
# Epoch 130/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1695 - mae: 0.3121
# Epoch 130: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1694 - mae: 0.3120 - val_loss: 0.4752 - val_mae: 0.5463 - learning_rate: 1.0000e-06
# Epoch 131/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1717 - mae: 0.3077
# Epoch 131: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1715 - mae: 0.3076 - val_loss: 0.4715 - val_mae: 0.5465 - learning_rate: 1.0000e-06
# Epoch 132/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1708 - mae: 0.3096
# Epoch 132: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1707 - mae: 0.3095 - val_loss: 0.4621 - val_mae: 0.5397 - learning_rate: 1.0000e-06
# Epoch 133/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1635 - mae: 0.3043
# Epoch 133: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1634 - mae: 0.3042 - val_loss: 0.4648 - val_mae: 0.5411 - learning_rate: 1.0000e-06
# Epoch 134/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1551 - mae: 0.2970
# Epoch 134: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1551 - mae: 0.2969 - val_loss: 0.4621 - val_mae: 0.5382 - learning_rate: 1.0000e-06
# Epoch 135/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1572 - mae: 0.3000
# Epoch 135: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1571 - mae: 0.3000 - val_loss: 0.4664 - val_mae: 0.5402 - learning_rate: 1.0000e-06
# Epoch 136/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1686 - mae: 0.3083
# Epoch 136: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1685 - mae: 0.3082 - val_loss: 0.4650 - val_mae: 0.5426 - learning_rate: 1.0000e-06
# Epoch 137/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1603 - mae: 0.3031
# Epoch 137: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1602 - mae: 0.3030 - val_loss: 0.4647 - val_mae: 0.5408 - learning_rate: 1.0000e-06
# Epoch 138/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1612 - mae: 0.2981
# Epoch 138: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1611 - mae: 0.2980 - val_loss: 0.4701 - val_mae: 0.5422 - learning_rate: 1.0000e-06
# Epoch 139/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1599 - mae: 0.2953
# Epoch 139: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1599 - mae: 0.2952 - val_loss: 0.4685 - val_mae: 0.5439 - learning_rate: 1.0000e-06
# Epoch 140/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1586 - mae: 0.2987
# Epoch 140: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1585 - mae: 0.2987 - val_loss: 0.4696 - val_mae: 0.5429 - learning_rate: 1.0000e-06
# Epoch 141/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1575 - mae: 0.2980
# Epoch 141: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1574 - mae: 0.2979 - val_loss: 0.4753 - val_mae: 0.5445 - learning_rate: 1.0000e-06
# Epoch 142/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1577 - mae: 0.3002
# Epoch 142: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1576 - mae: 0.3001 - val_loss: 0.4639 - val_mae: 0.5396 - learning_rate: 1.0000e-06
# Epoch 143/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1651 - mae: 0.3030
# Epoch 143: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1649 - mae: 0.3029 - val_loss: 0.4677 - val_mae: 0.5421 - learning_rate: 1.0000e-06
# Epoch 144/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1685 - mae: 0.3058
# Epoch 144: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1684 - mae: 0.3057 - val_loss: 0.4706 - val_mae: 0.5441 - learning_rate: 1.0000e-06
# Epoch 145/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1595 - mae: 0.2980
# Epoch 145: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1594 - mae: 0.2980 - val_loss: 0.4688 - val_mae: 0.5439 - learning_rate: 1.0000e-06
# Epoch 146/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1629 - mae: 0.2998
# Epoch 146: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1629 - mae: 0.2998 - val_loss: 0.4733 - val_mae: 0.5461 - learning_rate: 1.0000e-06
# Epoch 147/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1566 - mae: 0.2924
# Epoch 147: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1565 - mae: 0.2924 - val_loss: 0.4735 - val_mae: 0.5456 - learning_rate: 1.0000e-06
# Epoch 148/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1550 - mae: 0.2970
# Epoch 148: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1549 - mae: 0.2970 - val_loss: 0.4780 - val_mae: 0.5463 - learning_rate: 1.0000e-06
# Epoch 149/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1567 - mae: 0.2943
# Epoch 149: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1566 - mae: 0.2943 - val_loss: 0.4693 - val_mae: 0.5434 - learning_rate: 1.0000e-06
# Epoch 150/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1552 - mae: 0.2954
# Epoch 150: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1552 - mae: 0.2954 - val_loss: 0.4706 - val_mae: 0.5448 - learning_rate: 1.0000e-06
# Epoch 151/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1605 - mae: 0.2990
# Epoch 151: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1605 - mae: 0.2989 - val_loss: 0.4748 - val_mae: 0.5475 - learning_rate: 1.0000e-06
# Epoch 152/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1533 - mae: 0.2926
# Epoch 152: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1533 - mae: 0.2926 - val_loss: 0.4746 - val_mae: 0.5466 - learning_rate: 1.0000e-06
# Epoch 153/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1573 - mae: 0.2967
# Epoch 153: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.1573 - mae: 0.2967 - val_loss: 0.4701 - val_mae: 0.5439 - learning_rate: 1.0000e-06
# Epoch 154/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1505 - mae: 0.2906
# Epoch 154: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1504 - mae: 0.2906 - val_loss: 0.4733 - val_mae: 0.5471 - learning_rate: 1.0000e-06
# Epoch 155/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1634 - mae: 0.3034
# Epoch 155: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1633 - mae: 0.3033 - val_loss: 0.4677 - val_mae: 0.5411 - learning_rate: 1.0000e-06
# Epoch 156/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1519 - mae: 0.2882
# Epoch 156: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1519 - mae: 0.2882 - val_loss: 0.4690 - val_mae: 0.5422 - learning_rate: 1.0000e-06
# Epoch 157/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1678 - mae: 0.3062
# Epoch 157: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1677 - mae: 0.3061 - val_loss: 0.4725 - val_mae: 0.5459 - learning_rate: 1.0000e-06
# Epoch 158/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1566 - mae: 0.2978
# Epoch 158: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1566 - mae: 0.2977 - val_loss: 0.4699 - val_mae: 0.5426 - learning_rate: 1.0000e-06
# Epoch 159/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1558 - mae: 0.2960
# Epoch 159: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1557 - mae: 0.2959 - val_loss: 0.4724 - val_mae: 0.5438 - learning_rate: 1.0000e-06
# Epoch 160/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1569 - mae: 0.2957
# Epoch 160: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1568 - mae: 0.2957 - val_loss: 0.4663 - val_mae: 0.5400 - learning_rate: 1.0000e-06
# Epoch 161/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1576 - mae: 0.2976
# Epoch 161: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1575 - mae: 0.2976 - val_loss: 0.4655 - val_mae: 0.5405 - learning_rate: 1.0000e-06
# Epoch 162/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1581 - mae: 0.2972
# Epoch 162: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1580 - mae: 0.2971 - val_loss: 0.4679 - val_mae: 0.5420 - learning_rate: 1.0000e-06
# Epoch 163/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1539 - mae: 0.2974
# Epoch 163: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1539 - mae: 0.2974 - val_loss: 0.4709 - val_mae: 0.5420 - learning_rate: 1.0000e-06
# Epoch 164/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1576 - mae: 0.2989
# Epoch 164: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1574 - mae: 0.2988 - val_loss: 0.4597 - val_mae: 0.5363 - learning_rate: 1.0000e-06
# Epoch 165/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1538 - mae: 0.2955
# Epoch 165: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1537 - mae: 0.2955 - val_loss: 0.4811 - val_mae: 0.5477 - learning_rate: 1.0000e-06
# Epoch 166/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1575 - mae: 0.2979
# Epoch 166: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1574 - mae: 0.2978 - val_loss: 0.4717 - val_mae: 0.5437 - learning_rate: 1.0000e-06
# Epoch 167/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1529 - mae: 0.2961
# Epoch 167: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1529 - mae: 0.2960 - val_loss: 0.4709 - val_mae: 0.5406 - learning_rate: 1.0000e-06
# Epoch 168/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1481 - mae: 0.2891
# Epoch 168: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1481 - mae: 0.2891 - val_loss: 0.4741 - val_mae: 0.5439 - learning_rate: 1.0000e-06
# Epoch 169/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1567 - mae: 0.2962
# Epoch 169: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1566 - mae: 0.2961 - val_loss: 0.4713 - val_mae: 0.5434 - learning_rate: 1.0000e-06
# Epoch 170/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1535 - mae: 0.2940
# Epoch 170: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1535 - mae: 0.2940 - val_loss: 0.4689 - val_mae: 0.5429 - learning_rate: 1.0000e-06
# Epoch 171/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1524 - mae: 0.2958
# Epoch 171: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1524 - mae: 0.2958 - val_loss: 0.4731 - val_mae: 0.5449 - learning_rate: 1.0000e-06
# Epoch 172/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1658 - mae: 0.3014
# Epoch 172: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1657 - mae: 0.3013 - val_loss: 0.4797 - val_mae: 0.5491 - learning_rate: 1.0000e-06
# Epoch 173/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1549 - mae: 0.2978
# Epoch 173: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1548 - mae: 0.2977 - val_loss: 0.4747 - val_mae: 0.5453 - learning_rate: 1.0000e-06
# Epoch 174/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1507 - mae: 0.2930
# Epoch 174: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1506 - mae: 0.2929 - val_loss: 0.4779 - val_mae: 0.5486 - learning_rate: 1.0000e-06
# Epoch 175/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1517 - mae: 0.2925
# Epoch 175: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1517 - mae: 0.2924 - val_loss: 0.4713 - val_mae: 0.5440 - learning_rate: 1.0000e-06
# Epoch 176/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1529 - mae: 0.2919
# Epoch 176: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1528 - mae: 0.2918 - val_loss: 0.4790 - val_mae: 0.5473 - learning_rate: 1.0000e-06
# Epoch 177/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1550 - mae: 0.2988
# Epoch 177: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1550 - mae: 0.2988 - val_loss: 0.4676 - val_mae: 0.5413 - learning_rate: 1.0000e-06
# Epoch 178/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1530 - mae: 0.2908
# Epoch 178: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1530 - mae: 0.2907 - val_loss: 0.4907 - val_mae: 0.5523 - learning_rate: 1.0000e-06
# Epoch 179/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1583 - mae: 0.2946
# Epoch 179: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1582 - mae: 0.2946 - val_loss: 0.4682 - val_mae: 0.5416 - learning_rate: 1.0000e-06
# Epoch 180/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1543 - mae: 0.2942
# Epoch 180: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1543 - mae: 0.2941 - val_loss: 0.4620 - val_mae: 0.5400 - learning_rate: 1.0000e-06
# Epoch 181/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1601 - mae: 0.3009
# Epoch 181: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1600 - mae: 0.3008 - val_loss: 0.4774 - val_mae: 0.5478 - learning_rate: 1.0000e-06
# Epoch 182/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1524 - mae: 0.2926
# Epoch 182: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1523 - mae: 0.2925 - val_loss: 0.4631 - val_mae: 0.5387 - learning_rate: 1.0000e-06
# Epoch 183/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1512 - mae: 0.2937
# Epoch 183: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1512 - mae: 0.2937 - val_loss: 0.4709 - val_mae: 0.5436 - learning_rate: 1.0000e-06
# Epoch 184/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1524 - mae: 0.2941
# Epoch 184: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1523 - mae: 0.2940 - val_loss: 0.4760 - val_mae: 0.5457 - learning_rate: 1.0000e-06
# Epoch 185/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1485 - mae: 0.2917
# Epoch 185: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1485 - mae: 0.2917 - val_loss: 0.4709 - val_mae: 0.5445 - learning_rate: 1.0000e-06
# Epoch 186/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1440 - mae: 0.2825
# Epoch 186: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1440 - mae: 0.2825 - val_loss: 0.4729 - val_mae: 0.5455 - learning_rate: 1.0000e-06
# Epoch 187/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1393 - mae: 0.2790
# Epoch 187: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1393 - mae: 0.2790 - val_loss: 0.4674 - val_mae: 0.5428 - learning_rate: 1.0000e-06
# Epoch 188/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1503 - mae: 0.2888
# Epoch 188: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1502 - mae: 0.2887 - val_loss: 0.4645 - val_mae: 0.5419 - learning_rate: 1.0000e-06
# Epoch 189/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1463 - mae: 0.2872
# Epoch 189: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1463 - mae: 0.2872 - val_loss: 0.4780 - val_mae: 0.5483 - learning_rate: 1.0000e-06
# Epoch 190/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1535 - mae: 0.2963
# Epoch 190: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1534 - mae: 0.2962 - val_loss: 0.4681 - val_mae: 0.5429 - learning_rate: 1.0000e-06
# Epoch 191/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1542 - mae: 0.2929
# Epoch 191: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1541 - mae: 0.2928 - val_loss: 0.4793 - val_mae: 0.5484 - learning_rate: 1.0000e-06
# Epoch 192/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1499 - mae: 0.2897
# Epoch 192: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1499 - mae: 0.2896 - val_loss: 0.4691 - val_mae: 0.5433 - learning_rate: 1.0000e-06
# Epoch 193/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1520 - mae: 0.2898
# Epoch 193: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1520 - mae: 0.2898 - val_loss: 0.4694 - val_mae: 0.5431 - learning_rate: 1.0000e-06
# Epoch 194/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1488 - mae: 0.2914
# Epoch 194: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1487 - mae: 0.2914 - val_loss: 0.4745 - val_mae: 0.5479 - learning_rate: 1.0000e-06
# Epoch 195/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1463 - mae: 0.2875
# Epoch 195: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1463 - mae: 0.2874 - val_loss: 0.4762 - val_mae: 0.5463 - learning_rate: 1.0000e-06
# Epoch 196/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1493 - mae: 0.2903
# Epoch 196: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1492 - mae: 0.2902 - val_loss: 0.4807 - val_mae: 0.5497 - learning_rate: 1.0000e-06
# Epoch 197/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1458 - mae: 0.2896
# Epoch 197: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1457 - mae: 0.2895 - val_loss: 0.4759 - val_mae: 0.5483 - learning_rate: 1.0000e-06
# Epoch 198/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1516 - mae: 0.2886
# Epoch 198: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1516 - mae: 0.2885 - val_loss: 0.4720 - val_mae: 0.5447 - learning_rate: 1.0000e-06
# Epoch 199/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1563 - mae: 0.2983
# Epoch 199: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1562 - mae: 0.2981 - val_loss: 0.4761 - val_mae: 0.5475 - learning_rate: 1.0000e-06
# Epoch 200/200
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1487 - mae: 0.2893
# Epoch 200: val_mae did not improve from 0.51878
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1487 - mae: 0.2893 - val_loss: 0.4752 - val_mae: 0.5478 - learning_rate: 1.0000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === TEST METRICS (best checkpoint; de-normalized ŷ) ===
# MAE : 2.098156
# RMSE: 2.658788
# R^2 : 0.595091
# Saved best model → best_ann_hhb2.h5

# %%
print(X.shape , y.shape)
# Out:
# (3206, 404) (3206,)

# %%
# =====================
# Load BEST & evaluate — bring y back to original units
# =====================
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import numpy as np
import math
import tensorflow as tf
from tensorflow import keras

# Load without compile to avoid legacy alias issues, then (re)compile
best = keras.models.load_model(BEST_MODEL, compile=False)
best.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LR),
    loss=tf.keras.losses.MeanSquaredError(name="mse"),
    metrics=[keras.metrics.MeanAbsoluteError(name="mae"),
             keras.metrics.RootMeanSquaredError(name="rmse")]
)

# Predict in normalized target space
pred_test_n = best.predict(X_test_n, verbose=0).ravel().astype(np.float64)

# ---- DENORMALIZE to original HHB2 units (y_mean, y_std from training) ----
pred_test = pred_test_n * float(y_std) + float(y_mean)

# Metrics in ORIGINAL units
mae  = mean_absolute_error(y_test, pred_test)
rmse = math.sqrt(mean_squared_error(y_test, pred_test))
r2   = r2_score(y_test, pred_test)

print("\n=== TEST METRICS (best checkpoint, original units) ===")
print(f"MAE : {mae:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"R^2 : {r2:.6f}")
print(f"Loaded best model → {BEST_MODEL}")

# ---- Plot GT vs Pred (original units) ----
mse  = mean_squared_error(y_test, pred_test)
mare = np.mean(np.abs((pred_test - y_test) / np.clip(np.abs(y_test), 1e-8, None))) * 100.0

plt.figure(figsize=(5, 4.5), dpi=160)
plt.scatter(y_test, pred_test, s=14, alpha=0.6, edgecolors='none')

lo = float(min(np.min(y_test), np.min(pred_test)))
hi = float(max(np.max(y_test), np.max(pred_test)))
if not (np.isfinite(lo) and np.isfinite(hi)) or lo == hi:
    lo, hi = -1.0, 1.0

# Identity line
plt.plot([lo, hi], [lo, hi], 'k--', lw=1.2, alpha=0.8, label='y = x')

# Best-fit line (guard against degenerate variance)
if np.std(y_test) > 0:
    a, b = np.polyfit(y_test, pred_test, 1)
    xx = np.linspace(lo, hi, 200)
    plt.plot(xx, a * xx + b, lw=2, label=f'y = {a:.3f}x + {b:.3f}')

plt.xlabel("GT CCO2")
plt.ylabel("Predicted CCO2")
plt.title(f"Test: R²={r2:.3f}, MAE={mae:.3f}, RMSE={rmse:.3f}")
plt.text(0.02, 0.98, f"MSE = {mse:.2e}\nMARE = {mare:.2f}%",
         transform=plt.gca().transAxes, va='top', ha='left',
         color='#9c2a2a', fontsize=11, fontweight='bold')
plt.legend(loc='lower right', frameon=False)
plt.tight_layout()
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7cf3d012e020> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# === TEST METRICS (best checkpoint, original units) ===
# MAE : 2.098156
# RMSE: 2.658788
# R^2 : 0.595091
# Loaded best model → best_ann_hhb2.h5

# %%
# ---- Plot GT vs Pred (original units) ----
mse  = mean_squared_error(y_test, pred_test)
rmse = float(np.sqrt(mse))  # root mean square error
mare = np.mean(np.abs((pred_test - y_test) / np.clip(np.abs(y_test), 1e-8, None))) * 100.0

plt.figure(figsize=(5, 4.5), dpi=160)
plt.scatter(y_test, pred_test, s=14, alpha=0.6, edgecolors='none')

lo = float(min(np.min(y_test), np.min(pred_test)))
hi = float(max(np.max(y_test), np.max(pred_test)))
if not (np.isfinite(lo) and np.isfinite(hi)) or lo == hi:
    lo, hi = -1.0, 1.0

# Identity line only
plt.plot([lo, hi], [lo, hi], 'k--', lw=1.2, alpha=0.8, label='y = x')

plt.xlabel("GT CCO2")
plt.ylabel("Predicted CCO2")

# Replace MSE with RMSE in the textbox
plt.text(0.02, 0.98, f"RMSE = {rmse:.3f}\nMARE = {mare:.2f}%",
         transform=plt.gca().transAxes, va='top', ha='left',
         color='#9c2a2a', fontsize=11, fontweight='bold')

plt.legend(loc='lower right', frameon=False)
plt.tight_layout()
plt.show()

# %%
pred_test
# Out:
# array([ 3.44566159,  7.83663413, 10.09289824, 11.8302627 ,  4.76454693,
#         5.1899135 ,  6.39491873,  3.23379957,  5.85475225, 12.85251468,
#         3.93725066,  6.55586621,  8.28295815,  8.9986863 ,  7.32011419,
#         2.0827143 ,  8.32628373,  7.51288788,  5.2275375 ,  7.55721292,
#         6.10592774, 11.01634122,  9.80585418,  6.14789832,  5.149823  ,
#         4.88099571,  3.99437524,  8.38256061,  4.4192543 ,  5.42690819,
#         3.81072016,  2.69956143, 12.10942439,  6.38138165,  4.04090499,
#        10.51036511, 11.37995511,  3.62870839,  5.66738526,  4.97147956,
#         4.01119725,  3.17435357,  8.81840886,  2.86758702, 11.36087738,
#         7.44490531, 11.78870399,  2.65228735, 12.12336791,  7.45829071,
#         9.38266135,  4.19662158, 12.60096613,  5.28536347,  7.736214  ,
#        11.8880848 ,  3.29871498,  9.2221664 ,  6.25293384,  3.01192928,
#        11.7244204 ,  6.44380708, 10.95565511, 10.99155253,  5.33913369,
#         3.32291582,  3.98931912,  3.99141373,  9.86178572,  3.98215314,
#        10.29591399,  9.37754122,  4.82558451,  7.01435676,  9.38986548,
#         8.60054829,  2.40378178,  8.41677922,  5.55831674,  5.5041238 ,
#         5.78877817,  7.44176392, 11.69952309,  8.69097434, 13.12842054,
#         1.72807936,  8.16771845,  4.57732955, 11.76458746, 13.5807092 ,
#         9.30308979, 11.39186505,  8.59876624,  2.49456228,  9.73140042,
#         8.74076665,  6.48610036,  3.36453376,  4.68643131, 13.2182855 ,
#         9.05046575, 11.25551508,  5.04356017,  2.55137496,  1.90657564,
#         7.06258416,  8.4245114 ,  7.8447534 ,  5.82130906,  2.96694197,
#         6.86240724,  7.94594385,  9.89396876,  5.55223789,  9.68914678,
#         3.66197067,  1.81998487,  8.30492505,  7.91304862,  2.45156018,
#         8.9613389 , 10.53601735, 11.63018881,  8.43249335, 12.46110739,
#        11.24046   ,  6.46648449,  3.23885828, 12.24241974, 10.06625598,
#        12.51841405, 10.70300353,  9.66817875, 12.41830495,  5.48571435,
#         4.78440339, 11.2557525 ,  9.32317785,  6.22196789, 11.09489574,
#         5.95322917,  3.98003552, 10.64017135,  5.58766383,  3.91138763,
#         5.72389095,  5.6065635 ,  2.919836  , 12.23549686, 11.17558132,
#         8.64321974,  5.61151358,  2.39123226,  4.74342011, 11.75212225,
#         3.70557253,  5.08994845, 11.57595333, 11.9256025 , 10.86747328,
#         3.99984464])

# %%
y_test
# Out:
# array([ 9.766676  , 10.707838  , 10.586988  , 12.1616955 ,  4.4419684 ,
#         3.918287  ,  1.0655037 ,  3.4641855 ,  6.4927497 , 11.623365  ,
#         1.1607186 ,  6.598951  ,  4.3760505 ,  6.3462653 ,  7.2288337 ,
#         2.8233163 , 11.2241955 ,  9.63484   ,  3.4055917 ,  4.8118415 ,
#         4.4053473 , 10.909254  , 11.502516  , 10.513746  ,  8.679029  ,
#         1.4500252 ,  3.0210702 ,  6.3535895 ,  9.015944  ,  0.7139412 ,
#         2.0176523 ,  6.4231696 , 13.285963  ,  5.335523  ,  4.229566  ,
#         9.195387  , 12.77693   ,  8.195631  , 10.667555  ,  7.137281  ,
#         4.2515388 ,  7.6499763 ,  9.715406  ,  1.6917244 ,  5.4160895 ,
#        12.081129  ,  8.76692   ,  0.5235115 , 12.8648205 ,  5.895826  ,
#         6.7161384 ,  6.778394  , 11.242506  ,  4.9766364 ,  9.206373  ,
#         9.210035  ,  0.92634356, 10.2866955 ,  7.9942145 ,  3.7278574 ,
#        14.146559  ,  5.093824  , 10.403883  ,  9.869215  ,  5.200025  ,
#         7.3167243 ,  2.6841562 ,  1.8235604 ,  6.544019  ,  2.8343027 ,
#        12.531569  , 14.0366955 ,  4.7093024 ,  9.411451  ,  6.569654  ,
#        14.688551  ,  1.8931404 ,  8.675367  ,  6.4817634 ,  2.5047128 ,
#         8.499586  ,  7.7305427 , 11.297438  , 11.326735  , 14.241774  ,
#         1.9883553 , 10.246412  ,  4.1050544 , 12.487623  , 14.948561  ,
#         7.844068  , 12.751295  ,  1.9077889 ,  1.8858162 ,  9.678785  ,
#        11.407301  ,  9.415113  ,  1.878492  ,  3.9439218 , 12.982008  ,
#        10.887281  , 12.403395  ,  8.543531  ,  0.7835213 ,  1.54524   ,
#         5.328199  ,  2.6219003 , 12.121412  ,  9.3491955 ,  0.09138265,
#         6.9614997 ,  9.587233  ,  9.4261    ,  3.244459  ,  4.434644  ,
#         0.8274666 ,  0.80915606,  7.9575934 , 12.359449  ,  2.145826  ,
#         8.129713  ,  9.979078  , 13.38484   ,  9.927809  , 13.978102  ,
#        14.578688  , 12.806227  ,  2.5376718 , 10.2207775 ,  9.429762  ,
#        13.421461  , 13.703444  , 12.315504  , 14.128248  ,  7.111646  ,
#         6.0166755 , 14.831373  , 11.70027   ,  2.2190683 , 12.483961  ,
#         6.075269  ,  0.0327889 , 10.539381  ,  6.998121  ,  4.870435  ,
#         0.06574788,  5.569898  ,  5.0718513 ,  8.01985   , 14.476149  ,
#         7.6206794 ,  1.812574  ,  3.1675546 ,  5.4124274 ,  7.444898  ,
#         2.4204843 , 11.766188  , 14.900953  , 10.477125  , 11.583082  ,
#         0.270826  ], dtype=float32)
