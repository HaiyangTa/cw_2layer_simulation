# %% [markdown]
# ## FD_abs[hhb2] ANN Fitting

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
import pickle
from tqdm import tqdm
! pip install pmcx
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import StandardScaler
# Out:
# Collecting pmcx
#   Downloading pmcx-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.5.2

# %% [markdown]
# ### Read Simulation data

# %%
# -*- coding: utf-8 -*-
# Train an ANN to predict HHB2 from MCX simulation pickles.

import os, re, pickle, math, random
from pathlib import Path
from typing import Any, Iterable

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam

def build_FDnirsANN_model(input_dim=192,
                           optimizer=None,
                           loss='mse',
                           metrics=None, lr = 0.0003):
    """
    Constructs and returns the deep MLP regression model.

    Args:
      input_dim (int): size of the input feature vector
      optimizer (str or keras Optimizer): optimizer to use (default: Adam)
      loss (str): loss function (default: 'mse')
      metrics (list): list of metric names (default: ['mae'])

    Returns:
      model: a compiled keras Model instance
    """
    if optimizer is None:
        optimizer = Adam()
    if metrics is None:
        metrics = ['mae']

    model = Sequential([
        Input(shape=(input_dim,)),
        Dense(1000, activation='relu'),
        Dropout(0.1),

        Dense(4096, activation='relu'),
        Dropout(0.1),

        Dense(4096, activation='relu'),
        Dropout(0.2),

        Dense(8192, activation='relu'),
        Dropout(0.2),

        Dense(8192 * 2, activation='relu'),
        Dropout(0.2),

        Dense(8192, activation='relu'),
        Dropout(0.2),

        Dense(4096, activation='relu'),
        Dropout(0.2),

        Dense(2048, activation='relu'),
        Dropout(0.2),

        Dense(1024, activation='relu'),
        Dropout(0.2),

        Dense(512, activation='relu'),
        Dropout(0.1),

        Dense(256, activation='relu'),
        Dropout(0.1),

        Dense(64, activation='relu'),
        Dropout(0.1),

        Dense(32, activation='relu'),
        Dropout(0.0),

        Dense(1)
    ])

    model.compile(optimizer=Adam(learning_rate=lr), loss=loss, metrics=metrics)
    return model

# %%
from pathlib import Path
import os, math, random, pickle
from typing import Tuple, List

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

from tqdm.auto import tqdm
from concurrent.futures import ThreadPoolExecutor

# ---------------------
# Paths / Config
# ---------------------
RESULT_ROOT = Path('/content/drive/MyDrive/MCX_data/result_folder/cw_stage1')
GT_CSV      = Path('/content/drive/MyDrive/MCX_data/cw_stage1_csv/satge1.csv')

ID_COL      = 'ID'
TARGET_COL  = 'HHB2'

# Use 4 keys → 4 * 101 = 404 features per sample
KEYS_TO_USE: List[int] = [10, 20, 30, 40]
EACH_LEN    = 101
D_FEATURES  = len(KEYS_TO_USE) * EACH_LEN     # = 404
D_INPUT     = 2 * D_FEATURES                  # = 808  (concat x_i, x_j)

# Split ratios (80/10/10)
TEST_SIZE   = 0.10
VAL_SIZE    = 0.10
SEED        = 1337

# Pair construction
PAIRS_PER_ITEM = 6
INCLUDE_BOTH_DIRECTIONS = True  # also (j,i)

# Training
BATCH_SIZE  = 64
EPOCHS      = 200
LR          = 1e-4
BEST_MODEL  = 'best_pair_ann_808x1.h5'

# Loading perf
USE_THREADS = True
NUM_WORKERS = min(32, (os.cpu_count() or 8) * 2)

# ---------------------
# Repro & GPU mem growth
# ---------------------
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# ---------------------
# Helpers
# ---------------------
def _as_float1d(x, want_len):
    a = np.asarray(x, dtype=np.float32).ravel()
    if a.size == want_len:
        return a
    return None

def load_pickle_feature(pkl_path: Path, keys: List[int], each_len: int = EACH_LEN) -> np.ndarray:
    with open(pkl_path, 'rb') as f:
        obj = pickle.load(f)

    def get_key(d, k):
        if k in d: return d[k]
        sk = str(k)
        if sk in d: return d[sk]
        raise KeyError(f"Missing key {k} (/'{sk}') in {pkl_path}")

    parts = []
    for k in keys:
        v = _as_float1d(get_key(obj, k), each_len)
        parts.append(v)
    feat = np.concatenate(parts, axis=0).astype(np.float32)
    if feat.size != D_FEATURES:
        raise ValueError(f"{pkl_path}: got {feat.size}, expected {D_FEATURES}")
    return feat

# ---------------------
# Read GT and build ID -> target mapping
# ---------------------
if not GT_CSV.exists():
    raise FileNotFoundError(f"GT CSV not found: {GT_CSV}")

gt_df = pd.read_csv(GT_CSV)
cols_lc = {c.lower(): c for c in gt_df.columns}
if ID_COL.lower() not in cols_lc or TARGET_COL.lower() not in cols_lc:
    raise ValueError(f"CSV must contain '{ID_COL}' and '{TARGET_COL}'. Found: {list(gt_df.columns)}")
ID_COL_REAL     = cols_lc[ID_COL.lower()]
TARGET_COL_REAL = cols_lc[TARGET_COL.lower()]

id_to_target = dict(zip(gt_df[ID_COL_REAL].astype(int).tolist(),
                        gt_df[TARGET_COL_REAL].astype(float).tolist()))

# ---------------------
# Scan folders and collect simulations (ID, path)
# ---------------------
if not RESULT_ROOT.exists():
    raise FileNotFoundError(f"RESULT_ROOT not found: {RESULT_ROOT}")

sim_list: List[Tuple[int, Path]] = []
for sub in sorted(RESULT_ROOT.glob('part*')):
    if not sub.is_dir():
        continue
    for p in sorted(sub.glob('*.pkl')):
        try:
            pid = int(Path(p).stem)
        except Exception:
            continue
        if pid in id_to_target:
            sim_list.append((pid, p))

if not sim_list:
    raise RuntimeError("No matching (ID, pickle) pairs found. Check folders/filenames.")

print(f"Found {len(sim_list)} simulations with GT.")

# ---------------------
# Load base dataset once (X_base, y_base, ids_base)
# ---------------------
N_base = len(sim_list)
X_base = np.empty((N_base, D_FEATURES), dtype=np.float32)
y_base = np.empty(N_base, dtype=np.float32)
ids_base = np.empty(N_base, dtype=np.int64)

def _load_one(i_and_pair):
    i, (pid, p) = i_and_pair
    feat = load_pickle_feature(p, KEYS_TO_USE, EACH_LEN)
    return i, pid, feat

if USE_THREADS:
    with ThreadPoolExecutor(max_workers=NUM_WORKERS) as ex:
        for i, pid, feat in tqdm(ex.map(_load_one, enumerate(sim_list)),
                                 total=N_base, desc="Loading sims", unit="file"):
            X_base[i] = feat
            y_base[i] = float(id_to_target[pid])
            ids_base[i] = int(pid)
else:
    for i, (pid, p) in tqdm(enumerate(sim_list), total=N_base, desc="Loading sims", unit="file"):
        feat = load_pickle_feature(p, KEYS_TO_USE, EACH_LEN)
        X_base[i] = feat
        y_base[i] = float(id_to_target[pid])
        ids_base[i] = int(pid)

# ---------------------
# Split base simulations → 80/10/10 (no leakage)
# ---------------------
X_trainval_base, X_test_base, y_trainval_base, y_test_base = train_test_split(
    X_base, y_base, test_size=TEST_SIZE, random_state=SEED
)
val_frac_of_trainval = VAL_SIZE / (1.0 - TEST_SIZE)
X_train_base, X_val_base, y_train_base, y_val_base = train_test_split(
    X_trainval_base, y_trainval_base, test_size=val_frac_of_trainval, random_state=SEED
)

print(f"Base split sizes → train: {len(y_train_base)}, val: {len(y_val_base)}, test: {len(y_test_base)}")

# ---------------------
# Build pairs inside each split (CONCAT inputs, raw Δy target)
# ---------------------
rng = np.random.default_rng(SEED)


# make pairs.
def make_pairs_concat(X: np.ndarray, y: np.ndarray,
                      pairs_per_item: int = PAIRS_PER_ITEM,
                      include_both: bool = INCLUDE_BOTH_DIRECTIONS,
                      rng: np.random.Generator = rng) -> Tuple[np.ndarray, np.ndarray]:
    """
    Returns:
      Xc: [M, 2*D] where = concat(x_i, x_j)
      yp: [M] with yp = y_i - y_j
    """
    X = np.asarray(X, dtype=np.float32)
    y = np.asarray(y, dtype=np.float32).reshape(-1)
    N, D = X.shape
    if N < 2:
        raise ValueError("Need at least 2 samples to form pairs.")

    max_pairs = N * pairs_per_item * (2 if include_both else 1)
    Xc = np.empty((max_pairs, 2 * D), dtype=np.float32)
    yp = np.empty(max_pairs, dtype=np.float32)
    used = 0

    indices = np.arange(N)
    for i in range(N):
        cand = indices[indices != i]
        if cand.size == 0:
            continue
        partners = cand if pairs_per_item >= cand.size else rng.choice(cand, size=pairs_per_item, replace=False)

        for j in partners:
            # (x_i ; x_j)
            Xc[used, :D] = X[i]
            Xc[used, D:] = X[j]
            yp[used] = y[i] - y[j]
            used += 1

            if include_both:
                # (x_j ; x_i)
                Xc[used, :D] = X[j]
                Xc[used, D:] = X[i]
                yp[used] = y[j] - y[i]
                used += 1

    return Xc[:used], yp[:used]

X_train_concat, y_train_pairs = make_pairs_concat(X_train_base, y_train_base)
X_val_concat,   y_val_pairs   = make_pairs_concat(X_val_base,   y_val_base)
X_test_concat,  y_test_pairs  = make_pairs_concat(X_test_base,  y_test_base)

print(f"Pair sizes → train: {len(y_train_pairs)}, val: {len(y_val_pairs)}, test: {len(y_test_pairs)}")

# ---------------------
# Build (808,1) inputs (NO normalization) + raw Δy targets
# ---------------------
X_train_v21 = X_train_concat[..., None]   # (M, 808, 1)
X_val_v21   = X_val_concat[..., None]
X_test_v21  = X_test_concat[..., None]

y_train_raw = y_train_pairs.astype(np.float32).reshape(-1)
y_val_raw   = y_val_pairs.astype(np.float32).reshape(-1)
y_test_raw  = y_test_pairs.astype(np.float32).reshape(-1)

print("Input concat vector shape (train):", X_train_v21.shape)  # expect (M, 808, 1)
print("y_train shape:", y_train_raw.shape)

# ---------------------
# tf.data pipelines
# ---------------------
train_ds = (tf.data.Dataset.from_tensor_slices((X_train_v21, y_train_raw))
            .shuffle(8192, seed=SEED, reshuffle_each_iteration=True)
            .batch(BATCH_SIZE)
            .prefetch(tf.data.AUTOTUNE))

val_ds = (tf.data.Dataset.from_tensor_slices((X_val_v21, y_val_raw))
          .batch(BATCH_SIZE)
          .prefetch(tf.data.AUTOTUNE))

# ---------------------
# Train ANN (same model; just pass new input length)
# Requires your build_FDnirsANN_model to accept (input_len, lr, loss, etc.)
# ---------------------
# >>> Your model must be defined/imported elsewhere <<<
model = build_FDnirsANN_model(D_INPUT, lr=LR, loss='mse')

callbacks = [
    keras.callbacks.ModelCheckpoint(BEST_MODEL, monitor='val_mae', mode='min',
                                    save_best_only=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=10,
                                      min_lr=1e-6, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_mae', mode='min',
                                  patience=20, restore_best_weights=True, verbose=1),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

# Ensure the best version is saved
model.save(BEST_MODEL)

# ---------------------
# Evaluate on TEST pairs (raw Δy prediction)
# ---------------------
best = keras.models.load_model(BEST_MODEL, compile=False)
pred_test = best.predict(X_test_v21, batch_size=BATCH_SIZE, verbose=0).ravel().astype(np.float64)

mae  = mean_absolute_error(y_test_raw, pred_test)
rmse = math.sqrt(mean_squared_error(y_test_raw, pred_test))
r2   = r2_score(y_test_raw, pred_test)

print("\n=== TEST METRICS on pairwise ΔHHB2 (concat 808×1; RAW units) ===")
print(f"MAE : {mae:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"R^2 : {r2:.6f}")
print(f"Saved best model → {BEST_MODEL}")

# ---------------------
# Plot GT ΔHHB2 vs Pred ΔHHB2 (RAW)
# ---------------------
plt.figure(figsize=(5, 4.5), dpi=160)
plt.scatter(y_test_raw, pred_test, s=14, alpha=0.6, edgecolors='none')

lo = float(min(np.min(y_test_raw), np.min(pred_test)))
hi = float(max(np.max(y_test_raw), np.max(pred_test)))
if not np.isfinite(lo) or not np.isfinite(hi) or lo == hi:
    lo, hi = -1.0, 1.0

plt.plot([lo, hi], [lo, hi], 'k--', lw=1.2, alpha=0.8, label='y = x')

if np.std(y_test_raw) > 0:
    a, b = np.polyfit(y_test_raw, pred_test, 1)
    xx = np.linspace(lo, hi, 200)
    plt.plot(xx, a * xx + b, lw=2, label=f'y = {a:.3f}x + {b:.3f}')

mse  = mean_squared_error(y_test_raw, pred_test)
mare = np.mean(np.abs((pred_test - y_test_raw) / np.clip(np.abs(y_test_raw), 1e-8, None))) * 100.0

plt.xlabel("GT ΔHHB2 (y1 - y2)")
plt.ylabel("Pred ΔHHB2 (ŷ1 - ŷ2)")
plt.title(f"Pairwise Test (Concat 808×1): R² = {r2:.3f}, MAE = {mae:.3f}, RMSE = {rmse:.3f}")

txt = f"MSE = {mse:.2e}\nMARE = {mare:.2f}%"
plt.text(0.02, 0.98, txt,
         transform=plt.gca().transAxes, va='top', ha='left',
         color='#9c2a2a', fontsize=11, fontweight='bold')
plt.legend(loc='lower right', frameon=False)
plt.tight_layout()
plt.show()
# Out:
# Found 3500 simulations with GT.
# Loading sims:   0%|          | 0/3500 [00:00<?, ?file/s]
# Base split sizes → train: 2800, val: 350, test: 350
# Pair sizes → train: 33600, val: 4200, test: 4200
# Input concat vector shape (train): (33600, 808, 1)
# y_train shape: (33600,)
# Epoch 1/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 6430276.5000 - mae: 882.1704
# Epoch 1: val_mae improved from inf to 7.66019, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 66s 104ms/step - loss: 6420536.5000 - mae: 880.9488 - val_loss: 89.0191 - val_mae: 7.6602 - learning_rate: 1.0000e-04
# Epoch 2/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 877.0611 - mae: 22.4835
# Epoch 2: val_mae improved from 7.66019 to 7.59170, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - loss: 876.6878 - mae: 22.4784 - val_loss: 87.8990 - val_mae: 7.5917 - learning_rate: 1.0000e-04
# Epoch 3/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 344.1781 - mae: 14.3616
# Epoch 3: val_mae improved from 7.59170 to 6.89958, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 50s 95ms/step - loss: 344.0912 - mae: 14.3597 - val_loss: 70.7710 - val_mae: 6.8996 - learning_rate: 1.0000e-04
# Epoch 4/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 195.5206 - mae: 10.9174
# Epoch 4: val_mae improved from 6.89958 to 6.88576, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 195.4926 - mae: 10.9167 - val_loss: 70.6253 - val_mae: 6.8858 - learning_rate: 1.0000e-04
# Epoch 5/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 142.2905 - mae: 9.3790
# Epoch 5: val_mae improved from 6.88576 to 6.87290, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 49s 94ms/step - loss: 142.2795 - mae: 9.3787 - val_loss: 70.2363 - val_mae: 6.8729 - learning_rate: 1.0000e-04
# Epoch 6/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 115.7740 - mae: 8.5782
# Epoch 6: val_mae did not improve from 6.87290
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 115.7690 - mae: 8.5780 - val_loss: 70.8168 - val_mae: 6.8989 - learning_rate: 1.0000e-04
# Epoch 7/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 101.9362 - mae: 8.0802
# Epoch 7: val_mae did not improve from 6.87290
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 101.9335 - mae: 8.0802 - val_loss: 70.7711 - val_mae: 6.8959 - learning_rate: 1.0000e-04
# Epoch 8/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 91.4175 - mae: 7.7031
# Epoch 8: val_mae did not improve from 6.87290
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 91.4171 - mae: 7.7031 - val_loss: 70.4508 - val_mae: 6.8832 - learning_rate: 1.0000e-04
# Epoch 9/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 84.8396 - mae: 7.4331
# Epoch 9: val_mae improved from 6.87290 to 6.86022, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 49s 93ms/step - loss: 84.8402 - mae: 7.4331 - val_loss: 69.9048 - val_mae: 6.8602 - learning_rate: 1.0000e-04
# Epoch 10/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 82.1726 - mae: 7.3342
# Epoch 10: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 82.1737 - mae: 7.3343 - val_loss: 70.2458 - val_mae: 6.8730 - learning_rate: 1.0000e-04
# Epoch 11/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 79.7941 - mae: 7.2447
# Epoch 11: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 79.7962 - mae: 7.2448 - val_loss: 70.0012 - val_mae: 6.8644 - learning_rate: 1.0000e-04
# Epoch 12/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 78.0242 - mae: 7.1517
# Epoch 12: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 78.0258 - mae: 7.1518 - val_loss: 69.9703 - val_mae: 6.8627 - learning_rate: 1.0000e-04
# Epoch 13/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 76.5359 - mae: 7.1405
# Epoch 13: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 76.5364 - mae: 7.1405 - val_loss: 70.0888 - val_mae: 6.8690 - learning_rate: 1.0000e-04
# Epoch 14/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 75.4883 - mae: 7.0507
# Epoch 14: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 75.4892 - mae: 7.0508 - val_loss: 70.0601 - val_mae: 6.8657 - learning_rate: 1.0000e-04
# Epoch 15/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 73.6035 - mae: 6.9779
# Epoch 15: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 73.6046 - mae: 6.9779 - val_loss: 69.9194 - val_mae: 6.8611 - learning_rate: 1.0000e-04
# Epoch 16/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 72.9350 - mae: 6.9570
# Epoch 16: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 72.9375 - mae: 6.9571 - val_loss: 69.9586 - val_mae: 6.8616 - learning_rate: 1.0000e-04
# Epoch 17/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 72.7273 - mae: 6.9572
# Epoch 17: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 72.7278 - mae: 6.9572 - val_loss: 69.9373 - val_mae: 6.8605 - learning_rate: 1.0000e-04
# Epoch 18/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 71.2829 - mae: 6.8924
# Epoch 18: val_mae did not improve from 6.86022
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 71.2845 - mae: 6.8924 - val_loss: 70.0004 - val_mae: 6.8638 - learning_rate: 1.0000e-04
# Epoch 19/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 69.9767 - mae: 6.8085
# Epoch 19: val_mae improved from 6.86022 to 6.85964, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 50s 95ms/step - loss: 69.9791 - mae: 6.8086 - val_loss: 69.9073 - val_mae: 6.8596 - learning_rate: 1.0000e-04
# Epoch 20/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 70.0314 - mae: 6.8292
# Epoch 20: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 70.0327 - mae: 6.8293 - val_loss: 69.9777 - val_mae: 6.8630 - learning_rate: 1.0000e-04
# Epoch 21/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 68.9212 - mae: 6.7684
# Epoch 21: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 68.9232 - mae: 6.7685 - val_loss: 69.9379 - val_mae: 6.8614 - learning_rate: 1.0000e-04
# Epoch 22/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 69.0538 - mae: 6.7979
# Epoch 22: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 69.0540 - mae: 6.7979 - val_loss: 69.9594 - val_mae: 6.8624 - learning_rate: 1.0000e-04
# Epoch 23/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 68.5142 - mae: 6.7640
# Epoch 23: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 68.5148 - mae: 6.7640 - val_loss: 69.9536 - val_mae: 6.8615 - learning_rate: 1.0000e-04
# Epoch 24/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 68.6505 - mae: 6.7523
# Epoch 24: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 68.6510 - mae: 6.7523 - val_loss: 69.9119 - val_mae: 6.8603 - learning_rate: 1.0000e-04
# Epoch 25/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 67.1553 - mae: 6.6918
# Epoch 25: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 67.1575 - mae: 6.6919 - val_loss: 69.9692 - val_mae: 6.8628 - learning_rate: 1.0000e-04
# Epoch 26/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 67.7111 - mae: 6.7241
# Epoch 26: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 67.7124 - mae: 6.7241 - val_loss: 70.0595 - val_mae: 6.8668 - learning_rate: 1.0000e-04
# Epoch 27/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 67.1105 - mae: 6.7027
# Epoch 27: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 67.1122 - mae: 6.7027 - val_loss: 69.9226 - val_mae: 6.8608 - learning_rate: 1.0000e-04
# Epoch 28/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 67.3010 - mae: 6.7038
# Epoch 28: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 67.3015 - mae: 6.7038 - val_loss: 69.9852 - val_mae: 6.8636 - learning_rate: 1.0000e-04
# Epoch 29/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 66.8917 - mae: 6.6853
# Epoch 29: val_mae did not improve from 6.85964
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 66.8926 - mae: 6.6854 - val_loss: 69.9261 - val_mae: 6.8609 - learning_rate: 1.0000e-04
# Epoch 30/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 66.7364 - mae: 6.6774
# Epoch 30: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 66.7366 - mae: 6.6774 - val_loss: 69.9265 - val_mae: 6.8608 - learning_rate: 5.0000e-05
# Epoch 31/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 65.4220 - mae: 6.6118
# Epoch 31: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 65.4237 - mae: 6.6119 - val_loss: 69.9193 - val_mae: 6.8604 - learning_rate: 5.0000e-05
# Epoch 32/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 66.2483 - mae: 6.6629
# Epoch 32: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 66.2490 - mae: 6.6629 - val_loss: 69.9329 - val_mae: 6.8613 - learning_rate: 5.0000e-05
# Epoch 33/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 66.1875 - mae: 6.6586
# Epoch 33: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 66.1887 - mae: 6.6586 - val_loss: 69.9235 - val_mae: 6.8607 - learning_rate: 5.0000e-05
# Epoch 34/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 66.0435 - mae: 6.6374
# Epoch 34: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 66.0447 - mae: 6.6375 - val_loss: 69.9189 - val_mae: 6.8605 - learning_rate: 5.0000e-05
# Epoch 35/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 65.6671 - mae: 6.6184
# Epoch 35: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 65.6687 - mae: 6.6184 - val_loss: 69.9410 - val_mae: 6.8615 - learning_rate: 5.0000e-05
# Epoch 36/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 66.2800 - mae: 6.6666
# Epoch 36: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 66.2801 - mae: 6.6666 - val_loss: 69.9247 - val_mae: 6.8606 - learning_rate: 5.0000e-05
# Epoch 37/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 65.9362 - mae: 6.6390
# Epoch 37: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 65.9378 - mae: 6.6390 - val_loss: 69.9727 - val_mae: 6.8630 - learning_rate: 5.0000e-05
# Epoch 38/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 65.7879 - mae: 6.6278
# Epoch 38: val_mae did not improve from 6.85964
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 65.7896 - mae: 6.6279 - val_loss: 69.9197 - val_mae: 6.8606 - learning_rate: 5.0000e-05
# Epoch 39/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 65.4897 - mae: 6.6088
# Epoch 39: val_mae did not improve from 6.85964
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 65.4916 - mae: 6.6089 - val_loss: 69.9150 - val_mae: 6.8603 - learning_rate: 5.0000e-05
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 19.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === TEST METRICS on pairwise ΔHHB2 (concat 808×1; RAW units) ===
# MAE : 6.750502
# RMSE: 8.235316
# R^2 : -0.000112
# Saved best model → best_pair_ann_808x1.h5

# %% [markdown]
# ### Add standard scaler.

# %%
from pathlib import Path
import os, math, random, pickle
from typing import Tuple, List

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler  # <-- added

import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

from tqdm.auto import tqdm
from concurrent.futures import ThreadPoolExecutor

# ---------------------
# Paths / Config
# ---------------------
RESULT_ROOT = Path('/content/drive/MyDrive/MCX_data/result_folder/cw_stage1')
GT_CSV      = Path('/content/drive/MyDrive/MCX_data/cw_stage1_csv/satge1.csv')

ID_COL      = 'ID'
TARGET_COL  = 'HHB2'

# Use 4 keys → 4 * 101 = 404 features per sample
KEYS_TO_USE: List[int] = [10, 20, 30, 40]
EACH_LEN    = 101
D_FEATURES  = len(KEYS_TO_USE) * EACH_LEN     # = 404
D_INPUT     = 2 * D_FEATURES                  # = 808  (concat x_i, x_j)

# Split ratios (80/10/10)
TEST_SIZE   = 0.10
VAL_SIZE    = 0.10
SEED        = 1337

# Pair construction
PAIRS_PER_ITEM = 10
INCLUDE_BOTH_DIRECTIONS = True  # also (j,i)

# Training
BATCH_SIZE  = 64
EPOCHS      = 200
LR          = 1e-4
BEST_MODEL  = 'best_pair_ann_808x1.h5'

# Loading perf
USE_THREADS = True
NUM_WORKERS = min(32, (os.cpu_count() or 8) * 2)

# ---------------------
# Repro & GPU mem growth
# ---------------------
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# ---------------------
# Helpers
# ---------------------
def _as_float1d(x, want_len):
    a = np.asarray(x, dtype=np.float32).ravel()
    if a.size == want_len:
        return a
    # if your pickles might have different lengths, replace with resample/interp
    raise ValueError(f"Feature length {a.size} != expected {want_len}")

def load_pickle_feature(pkl_path: Path, keys: List[int], each_len: int = EACH_LEN) -> np.ndarray:
    with open(pkl_path, 'rb') as f:
        obj = pickle.load(f)

    def get_key(d, k):
        if k in d: return d[k]
        sk = str(k)
        if sk in d: return d[sk]
        raise KeyError(f"Missing key {k} (/'{sk}') in {pkl_path}")

    parts = []
    for k in keys:
        v = _as_float1d(get_key(obj, k), each_len)
        parts.append(v)
    feat = np.concatenate(parts, axis=0).astype(np.float32)
    if feat.size != D_FEATURES:
        raise ValueError(f"{pkl_path}: got {feat.size}, expected {D_FEATURES}")
    return feat

# ---------------------
# Read GT and build ID -> target mapping
# ---------------------
if not GT_CSV.exists():
    raise FileNotFoundError(f"GT CSV not found: {GT_CSV}")

gt_df = pd.read_csv(GT_CSV)
cols_lc = {c.lower(): c for c in gt_df.columns}
if ID_COL.lower() not in cols_lc or TARGET_COL.lower() not in cols_lc:
    raise ValueError(f"CSV must contain '{ID_COL}' and '{TARGET_COL}'. Found: {list(gt_df.columns)}")
ID_COL_REAL     = cols_lc[ID_COL.lower()]
TARGET_COL_REAL = cols_lc[TARGET_COL.lower()]

id_to_target = dict(zip(gt_df[ID_COL_REAL].astype(int).tolist(),
                        gt_df[TARGET_COL_REAL].astype(float).tolist()))

# ---------------------
# Scan folders and collect simulations (ID, path)
# ---------------------
if not RESULT_ROOT.exists():
    raise FileNotFoundError(f"RESULT_ROOT not found: {RESULT_ROOT}")

sim_list: List[Tuple[int, Path]] = []
for sub in sorted(RESULT_ROOT.glob('part*')):
    if not sub.is_dir():
        continue
    for p in sorted(sub.glob('*.pkl')):
        try:
            pid = int(Path(p).stem)
        except Exception:
            continue
        if pid in id_to_target:
            sim_list.append((pid, p))

if not sim_list:
    raise RuntimeError("No matching (ID, pickle) pairs found. Check folders/filenames.")

print(f"Found {len(sim_list)} simulations with GT.")

# ---------------------
# Load base dataset once (X_base, y_base, ids_base)
# ---------------------
N_base = len(sim_list)
X_base = np.empty((N_base, D_FEATURES), dtype=np.float32)
y_base = np.empty(N_base, dtype=np.float32)
ids_base = np.empty(N_base, dtype=np.int64)

def _load_one(i_and_pair):
    i, (pid, p) = i_and_pair
    feat = load_pickle_feature(p, KEYS_TO_USE, EACH_LEN)
    return i, pid, feat

if USE_THREADS:
    with ThreadPoolExecutor(max_workers=NUM_WORKERS) as ex:
        for i, pid, feat in tqdm(ex.map(_load_one, enumerate(sim_list)),
                                 total=N_base, desc="Loading sims", unit="file"):
            X_base[i] = feat
            y_base[i] = float(id_to_target[pid])
            ids_base[i] = int(pid)
else:
    for i, (pid, p) in tqdm(enumerate(sim_list), total=N_base, desc="Loading sims", unit="file"):
        feat = load_pickle_feature(p, KEYS_TO_USE, EACH_LEN)
        X_base[i] = feat
        y_base[i] = float(id_to_target[pid])
        ids_base[i] = int(pid)

# ---------------------
# Split base simulations → 80/10/10 (no leakage)
# ---------------------
X_trainval_base, X_test_base, y_trainval_base, y_test_base = train_test_split(
    X_base, y_base, test_size=TEST_SIZE, random_state=SEED
)
val_frac_of_trainval = VAL_SIZE / (1.0 - TEST_SIZE)
X_train_base, X_val_base, y_train_base, y_val_base = train_test_split(
    X_trainval_base, y_trainval_base, test_size=val_frac_of_trainval, random_state=SEED
)

print(f"Base split sizes → train: {len(y_train_base)}, val: {len(y_val_base)}, test: {len(y_test_base)}")

# ---------------------
# Build pairs inside each split (CONCAT inputs, raw Δy target)
# ---------------------
rng = np.random.default_rng(SEED)

def make_pairs_concat(X: np.ndarray, y: np.ndarray,
                      pairs_per_item: int = PAIRS_PER_ITEM,
                      include_both: bool = INCLUDE_BOTH_DIRECTIONS,
                      rng: np.random.Generator = rng) -> Tuple[np.ndarray, np.ndarray]:
    """
    Returns:
      Xc: [M, 2*D] where = concat(x_i, x_j)
      yp: [M] with yp = y_i - y_j
    """
    X = np.asarray(X, dtype=np.float32)
    y = np.asarray(y, dtype=np.float32).reshape(-1)
    N, D = X.shape
    if N < 2:
        raise ValueError("Need at least 2 samples to form pairs.")

    max_pairs = N * pairs_per_item * (2 if include_both else 1)
    Xc = np.empty((max_pairs, 2 * D), dtype=np.float32)
    yp = np.empty(max_pairs, dtype=np.float32)
    used = 0

    indices = np.arange(N)
    for i in range(N):
        cand = indices[indices != i]
        if cand.size == 0:
            continue
        partners = cand if pairs_per_item >= cand.size else rng.choice(cand, size=pairs_per_item, replace=False)

        for j in partners:
            # (x_i ; x_j)
            Xc[used, :D] = X[i]
            Xc[used, D:] = X[j]
            yp[used] = y[i] - y[j]
            used += 1

            if include_both:
                # (x_j ; x_i)
                Xc[used, :D] = X[j]
                Xc[used, D:] = X[i]
                yp[used] = y[j] - y[i]
                used += 1

    return Xc[:used], yp[:used]

X_train_concat, y_train_pairs = make_pairs_concat(X_train_base, y_train_base)
X_val_concat,   y_val_pairs   = make_pairs_concat(X_val_base,   y_val_base)
X_test_concat,  y_test_pairs  = make_pairs_concat(X_test_base,  y_test_base)

print(f"Pair sizes → train: {len(y_train_pairs)}, val: {len(y_val_pairs)}, test: {len(y_test_pairs)}")

# ---------------------
# STANDARDIZE AFTER PAIRING (fit on TRAIN only)
# ---------------------
scaler_X = StandardScaler()  # mean/std across features of the 808-dim vector
X_train_scaled = scaler_X.fit_transform(X_train_concat)
X_val_scaled   = scaler_X.transform(X_val_concat)
X_test_scaled  = scaler_X.transform(X_test_concat)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train_pairs.reshape(-1, 1)).astype(np.float32).ravel()
y_val_scaled   = scaler_y.transform(y_val_pairs.reshape(-1, 1)).astype(np.float32).ravel()
# keep raw test target for metrics; model preds will be inverse-transformed later
y_test_raw     = y_test_pairs.astype(np.float32).reshape(-1)

# Build (808,1) inputs for the ANN
X_train_v21 = X_train_scaled.astype(np.float32)[..., None]   # (M, 808, 1)
X_val_v21   = X_val_scaled.astype(np.float32)[..., None]
X_test_v21  = X_test_scaled.astype(np.float32)[..., None]

print("Input concat vector shape (train):", X_train_v21.shape)
print("y_train (scaled) shape:", y_train_scaled.shape)

# ---------------------
# tf.data pipelines
# ---------------------
train_ds = (tf.data.Dataset.from_tensor_slices((X_train_v21, y_train_scaled))
            .shuffle(8192, seed=SEED, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE))

val_ds = (tf.data.Dataset.from_tensor_slices((X_val_v21, y_val_scaled)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE))

# ---------------------
# Train ANN (same model; just pass new input length)
# ---------------------
# >>> Your build_FDnirsANN_model must accept (input_len, lr, loss, etc.) and output a scalar <<<
model = build_FDnirsANN_model(D_INPUT, lr=LR, loss='mse')

callbacks = [
    keras.callbacks.ModelCheckpoint(BEST_MODEL, monitor='val_mae', mode='min',
                                    save_best_only=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=10,
                                      min_lr=1e-6, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_mae', mode='min',
                                  patience=20, restore_best_weights=True, verbose=1),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

# Ensure the best version is saved
model.save(BEST_MODEL)

# ---------------------
# Evaluate on TEST pairs
#  - Model outputs normalized Δy; invert to RAW units for metrics/plots
# ---------------------
best = keras.models.load_model(BEST_MODEL, compile=False)
pred_test_scaled = best.predict(X_test_v21, batch_size=BATCH_SIZE, verbose=0).ravel().astype(np.float64)
pred_test_raw = scaler_y.inverse_transform(pred_test_scaled.reshape(-1, 1)).ravel()

mae  = mean_absolute_error(y_test_raw, pred_test_raw)
rmse = math.sqrt(mean_squared_error(y_test_raw, pred_test_raw))
r2   = r2_score(y_test_raw, pred_test_raw)

print("\n=== TEST METRICS on pairwise ΔHHB2 (concat 808×1; de-normalized) ===")
print(f"MAE : {mae:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"R^2 : {r2:.6f}")
print(f"Saved best model → {BEST_MODEL}")

# ---------------------
# Plot GT ΔHHB2 vs Pred ΔHHB2 (RAW units)
# ---------------------
plt.figure(figsize=(5, 4.5), dpi=160)
plt.scatter(y_test_raw, pred_test_raw, s=14, alpha=0.6, edgecolors='none')

lo = float(min(np.min(y_test_raw), np.min(pred_test_raw)))
hi = float(max(np.max(y_test_raw), np.max(pred_test_raw)))
if not np.isfinite(lo) or not np.isfinite(hi) or lo == hi:
    lo, hi = -1.0, 1.0

plt.plot([lo, hi], [lo, hi], 'k--', lw=1.2, alpha=0.8, label='y = x')

if np.std(y_test_raw) > 0:
    a, b = np.polyfit(y_test_raw, pred_test_raw, 1)
    xx = np.linspace(lo, hi, 200)
    plt.plot(xx, a * xx + b, lw=2, label=f'y = {a:.3f}x + {b:.3f}')

mse  = mean_squared_error(y_test_raw, pred_test_raw)
mare = np.mean(np.abs((pred_test_raw - y_test_raw) / np.clip(np.abs(y_test_raw), 1e-8, None))) * 100.0

plt.xlabel("GT ΔHHB2 (y1 - y2)")
plt.ylabel("Pred ΔHHB2 (ŷ1 - ŷ2)")
plt.title(f"Pairwise Test (Concat 808×1): R² = {r2:.3f}, MAE = {mae:.3f}, RMSE = {rmse:.3f}")

txt = f"MSE = {mse:.2e}\nMARE = {mare:.2f}%"
plt.text(0.02, 0.98, txt,
         transform=plt.gca().transAxes, va='top', ha='left',
         color='#9c2a2a', fontsize=11, fontweight='bold')
plt.legend(loc='lower right', frameon=False)
plt.tight_layout()
plt.show()
# Out:
# Found 3500 simulations with GT.
# Loading sims:   0%|          | 0/3500 [00:00<?, ?file/s]
# Base split sizes → train: 2800, val: 350, test: 350
# Pair sizes → train: 33600, val: 4200, test: 4200
# Input concat vector shape (train): (33600, 808, 1)
# y_train (scaled) shape: (33600,)
# Epoch 1/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9940 - mae: 0.8146
# Epoch 1: val_mae improved from inf to 0.84312, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 66s 105ms/step - loss: 0.9940 - mae: 0.8146 - val_loss: 1.0558 - val_mae: 0.8431 - learning_rate: 1.0000e-04
# Epoch 2/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9894 - mae: 0.8141
# Epoch 2: val_mae did not improve from 0.84312
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 0.9894 - mae: 0.8141 - val_loss: 1.0669 - val_mae: 0.8467 - learning_rate: 1.0000e-04
# Epoch 3/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9517 - mae: 0.7963
# Epoch 3: val_mae improved from 0.84312 to 0.83273, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 49s 93ms/step - loss: 0.9517 - mae: 0.7963 - val_loss: 1.0298 - val_mae: 0.8327 - learning_rate: 1.0000e-04
# Epoch 4/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.9297 - mae: 0.7863
# Epoch 4: val_mae improved from 0.83273 to 0.82366, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.9297 - mae: 0.7863 - val_loss: 1.0132 - val_mae: 0.8237 - learning_rate: 1.0000e-04
# Epoch 5/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.9017 - mae: 0.7744
# Epoch 5: val_mae improved from 0.82366 to 0.80650, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.9017 - mae: 0.7744 - val_loss: 0.9638 - val_mae: 0.8065 - learning_rate: 1.0000e-04
# Epoch 6/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8801 - mae: 0.7637
# Epoch 6: val_mae improved from 0.80650 to 0.79595, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.8801 - mae: 0.7637 - val_loss: 0.9378 - val_mae: 0.7959 - learning_rate: 1.0000e-04
# Epoch 7/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8484 - mae: 0.7486
# Epoch 7: val_mae improved from 0.79595 to 0.78533, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - loss: 0.8484 - mae: 0.7487 - val_loss: 0.9161 - val_mae: 0.7853 - learning_rate: 1.0000e-04
# Epoch 8/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8264 - mae: 0.7381
# Epoch 8: val_mae did not improve from 0.78533
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.8264 - mae: 0.7382 - val_loss: 0.9199 - val_mae: 0.7881 - learning_rate: 1.0000e-04
# Epoch 9/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.8164 - mae: 0.7336
# Epoch 9: val_mae improved from 0.78533 to 0.78014, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.8164 - mae: 0.7336 - val_loss: 0.9049 - val_mae: 0.7801 - learning_rate: 1.0000e-04
# Epoch 10/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7879 - mae: 0.7218
# Epoch 10: val_mae did not improve from 0.78014
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.7879 - mae: 0.7218 - val_loss: 0.9299 - val_mae: 0.7875 - learning_rate: 1.0000e-04
# Epoch 11/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7783 - mae: 0.7151
# Epoch 11: val_mae improved from 0.78014 to 0.75633, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.7783 - mae: 0.7151 - val_loss: 0.8552 - val_mae: 0.7563 - learning_rate: 1.0000e-04
# Epoch 12/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.7505 - mae: 0.7031
# Epoch 12: val_mae did not improve from 0.75633
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 69ms/step - loss: 0.7505 - mae: 0.7031 - val_loss: 0.8630 - val_mae: 0.7624 - learning_rate: 1.0000e-04
# Epoch 13/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7412 - mae: 0.6978
# Epoch 13: val_mae improved from 0.75633 to 0.74640, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 50s 96ms/step - loss: 0.7412 - mae: 0.6978 - val_loss: 0.8359 - val_mae: 0.7464 - learning_rate: 1.0000e-04
# Epoch 14/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7149 - mae: 0.6862
# Epoch 14: val_mae improved from 0.74640 to 0.74076, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.7150 - mae: 0.6862 - val_loss: 0.8259 - val_mae: 0.7408 - learning_rate: 1.0000e-04
# Epoch 15/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.7043 - mae: 0.6791
# Epoch 15: val_mae improved from 0.74076 to 0.73377, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.7043 - mae: 0.6791 - val_loss: 0.8054 - val_mae: 0.7338 - learning_rate: 1.0000e-04
# Epoch 16/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6851 - mae: 0.6718
# Epoch 16: val_mae improved from 0.73377 to 0.72873, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 51s 97ms/step - loss: 0.6852 - mae: 0.6718 - val_loss: 0.8015 - val_mae: 0.7287 - learning_rate: 1.0000e-04
# Epoch 17/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6847 - mae: 0.6690
# Epoch 17: val_mae improved from 0.72873 to 0.71324, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 50s 94ms/step - loss: 0.6847 - mae: 0.6690 - val_loss: 0.7671 - val_mae: 0.7132 - learning_rate: 1.0000e-04
# Epoch 18/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6653 - mae: 0.6597
# Epoch 18: val_mae improved from 0.71324 to 0.71065, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.6653 - mae: 0.6597 - val_loss: 0.7635 - val_mae: 0.7106 - learning_rate: 1.0000e-04
# Epoch 19/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6546 - mae: 0.6526
# Epoch 19: val_mae did not improve from 0.71065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.6546 - mae: 0.6526 - val_loss: 0.8498 - val_mae: 0.7473 - learning_rate: 1.0000e-04
# Epoch 20/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6601 - mae: 0.6571
# Epoch 20: val_mae did not improve from 0.71065
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.6601 - mae: 0.6571 - val_loss: 0.7643 - val_mae: 0.7128 - learning_rate: 1.0000e-04
# Epoch 21/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6335 - mae: 0.6423
# Epoch 21: val_mae improved from 0.71065 to 0.70964, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 48s 92ms/step - loss: 0.6335 - mae: 0.6423 - val_loss: 0.7625 - val_mae: 0.7096 - learning_rate: 1.0000e-04
# Epoch 22/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6382 - mae: 0.6434
# Epoch 22: val_mae improved from 0.70964 to 0.68767, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 52s 100ms/step - loss: 0.6382 - mae: 0.6434 - val_loss: 0.7151 - val_mae: 0.6877 - learning_rate: 1.0000e-04
# Epoch 23/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6209 - mae: 0.6353
# Epoch 23: val_mae did not improve from 0.68767
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.6209 - mae: 0.6353 - val_loss: 0.7383 - val_mae: 0.6991 - learning_rate: 1.0000e-04
# Epoch 24/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6297 - mae: 0.6403
# Epoch 24: val_mae did not improve from 0.68767
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.6297 - mae: 0.6404 - val_loss: 0.7665 - val_mae: 0.7077 - learning_rate: 1.0000e-04
# Epoch 25/200
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.6382 - mae: 0.6453
# Epoch 25: val_mae did not improve from 0.68767
# 525/525 ━━━━━━━━━━━━━━━━━━━━ 36s 68ms/step - loss: 0.6382 - mae: 0.6453 - val_loss: 0.7412 - val_mae: 0.6973 - learning_rate: 1.0000e-04
# Epoch 26/200
#  47/525 ━━━━━━━━━━━━━━━━━━━━ 32s 67ms/step - loss: 0.5526 - mae: 0.6006
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3904902633.py in <cell line: 0>()
#     270 ]
#     271
# --> 272 history = model.fit(
#     273     train_ds,
#     274     validation_data=val_ds,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375                 for step, iterator in epoch_iterator:
#     376                     callbacks.on_train_batch_begin(step)
# --> 377                     logs = self.train_function(iterator)
#     378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     219             ):
#     220                 opt_outputs = multi_step_on_iterator(iterator)
# --> 221                 if not opt_outputs.has_value():
#     222                     raise StopIteration
#     223                 return opt_outputs.get_value()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/optional_ops.py in has_value(self, name)
#     174   def has_value(self, name=None):
#     175     with ops.colocate_with(self._variant_tensor):
# --> 176       return gen_optional_ops.optional_has_value(
#     177           self._variant_tensor, name=name
#     178       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_optional_ops.py in optional_has_value(optional, name)
#     170   if tld.is_eager:
#     171     try:
# --> 172       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173         _ctx, "OptionalHasValue", name, optional)
#     174       return _result
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2 branches model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Lambda, Concatenate
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

def build_FDnirsANN_model(input_dim=808,
                          optimizer=None,
                          loss='mse',
                          metrics=None,
                          lr=3e-4):
    """
    One-input (808x1) → Flatten → split into two 404-d vectors →
    two branches → concat → head → scalar.
    """
    if optimizer is None:
        optimizer = Adam(learning_rate=lr)
    if metrics is None:
        metrics = ['mae']

    # --- single 808x1 input (matches your X_*_v21 tensors) ---
    inp = Input(shape=(input_dim, 1), name="concat_808x1")  # e.g., (808,1)
    flat = Flatten(name="flatten_808")(inp)                 # -> (808,)

    # --- split into two 404-d vectors ---
    half = input_dim // 2                                   # 404
    x_a = Lambda(lambda t: t[:, :half],  name="x_a_404")(flat)
    x_b = Lambda(lambda t: t[:, half:], name="x_b_404")(flat)

    # --- branch definition (unshared; tweak sizes if you want) ---
    def branch(z, prefix):
        z = Dense(1024, activation='relu', name=f'{prefix}_d1')(z)
        z = Dropout(0.2, name=f'{prefix}_drop1')(z)
        z = Dense(512, activation='relu', name=f'{prefix}_d2')(z)
        z = Dropout(0.2, name=f'{prefix}_drop2')(z)
        z = Dense(256, activation='relu', name=f'{prefix}_d3')(z)
        z = Dropout(0.1, name=f'{prefix}_drop3')(z)
        return z

    a = branch(x_a, "branchA")
    b = branch(x_b, "branchB")

    # --- horizontal concat + head ---
    merged = Concatenate(name="concat_branches")([a, b])
    h = Dense(512, activation='relu', name='head_d1')(merged)
    h = Dropout(0.2, name='head_drop1')(h)
    h = Dense(128, activation='relu', name='head_d2')(h)
    h = Dropout(0.1, name='head_drop2')(h)
    out = Dense(1, activation='linear', name='y_hat')(h)

    model = Model(inputs=inp, outputs=out, name="FDnirs_808x1_split_2branch")
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
from pathlib import Path
import os, math, random, pickle
from typing import Tuple, List

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler  # <-- added

import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

from tqdm.auto import tqdm
from concurrent.futures import ThreadPoolExecutor

# ---------------------
# Paths / Config
# ---------------------
RESULT_ROOT = Path('/content/drive/MyDrive/MCX_data/result_folder/cw_stage1')
GT_CSV      = Path('/content/drive/MyDrive/MCX_data/cw_stage1_csv/satge1.csv')

ID_COL      = 'ID'
TARGET_COL  = 'CCO2'

# Use 4 keys → 4 * 101 = 404 features per sample
KEYS_TO_USE: List[int] = [10, 20, 30, 40]
EACH_LEN    = 101
D_FEATURES  = len(KEYS_TO_USE) * EACH_LEN     # = 404
D_INPUT     = 2 * D_FEATURES                  # = 808  (concat x_i, x_j)

# Split ratios (80/10/10)
TEST_SIZE   = 0.10
VAL_SIZE    = 0.10
SEED        = 1337

# Pair construction
PAIRS_PER_ITEM = 20
INCLUDE_BOTH_DIRECTIONS = True  # also (j,i)

# Training
BATCH_SIZE  = 64
EPOCHS      = 200
LR          = 1e-4
BEST_MODEL  = 'best_pair_ann_808x1.h5'

# Loading perf
USE_THREADS = True
NUM_WORKERS = min(32, (os.cpu_count() or 8) * 2)

# ---------------------
# Repro & GPU mem growth
# ---------------------
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
for g in tf.config.list_physical_devices('GPU'):
    try:
        tf.config.experimental.set_memory_growth(g, True)
    except Exception:
        pass

# ---------------------
# Helpers
# ---------------------
def _as_float1d(x, want_len):
    a = np.asarray(x, dtype=np.float32).ravel()
    if a.size == want_len:
        return a
    # if your pickles might have different lengths, replace with resample/interp
    raise ValueError(f"Feature length {a.size} != expected {want_len}")

def load_pickle_feature(pkl_path: Path, keys: List[int], each_len: int = EACH_LEN) -> np.ndarray:
    with open(pkl_path, 'rb') as f:
        obj = pickle.load(f)

    def get_key(d, k):
        if k in d: return d[k]
        sk = str(k)
        if sk in d: return d[sk]
        raise KeyError(f"Missing key {k} (/'{sk}') in {pkl_path}")

    parts = []
    for k in keys:
        v = _as_float1d(get_key(obj, k), each_len)
        parts.append(v)
    feat = np.concatenate(parts, axis=0).astype(np.float32)
    if feat.size != D_FEATURES:
        raise ValueError(f"{pkl_path}: got {feat.size}, expected {D_FEATURES}")
    return feat

# ---------------------
# Read GT and build ID -> target mapping
# ---------------------
if not GT_CSV.exists():
    raise FileNotFoundError(f"GT CSV not found: {GT_CSV}")

gt_df = pd.read_csv(GT_CSV)
cols_lc = {c.lower(): c for c in gt_df.columns}
if ID_COL.lower() not in cols_lc or TARGET_COL.lower() not in cols_lc:
    raise ValueError(f"CSV must contain '{ID_COL}' and '{TARGET_COL}'. Found: {list(gt_df.columns)}")
ID_COL_REAL     = cols_lc[ID_COL.lower()]
TARGET_COL_REAL = cols_lc[TARGET_COL.lower()]

id_to_target = dict(zip(gt_df[ID_COL_REAL].astype(int).tolist(),
                        gt_df[TARGET_COL_REAL].astype(float).tolist()))

# ---------------------
# Scan folders and collect simulations (ID, path)
# ---------------------
if not RESULT_ROOT.exists():
    raise FileNotFoundError(f"RESULT_ROOT not found: {RESULT_ROOT}")

sim_list: List[Tuple[int, Path]] = []
for sub in sorted(RESULT_ROOT.glob('part*')):
    if not sub.is_dir():
        continue
    for p in sorted(sub.glob('*.pkl')):
        try:
            pid = int(Path(p).stem)
        except Exception:
            continue
        if pid in id_to_target:
            sim_list.append((pid, p))

if not sim_list:
    raise RuntimeError("No matching (ID, pickle) pairs found. Check folders/filenames.")

print(f"Found {len(sim_list)} simulations with GT.")

# ---------------------
# Load base dataset once (X_base, y_base, ids_base)
# ---------------------
N_base = len(sim_list)
X_base = np.empty((N_base, D_FEATURES), dtype=np.float32)
y_base = np.empty(N_base, dtype=np.float32)
ids_base = np.empty(N_base, dtype=np.int64)

def _load_one(i_and_pair):
    i, (pid, p) = i_and_pair
    feat = load_pickle_feature(p, KEYS_TO_USE, EACH_LEN)
    return i, pid, feat

if USE_THREADS:
    with ThreadPoolExecutor(max_workers=NUM_WORKERS) as ex:
        for i, pid, feat in tqdm(ex.map(_load_one, enumerate(sim_list)),
                                 total=N_base, desc="Loading sims", unit="file"):
            X_base[i] = feat
            y_base[i] = float(id_to_target[pid])
            ids_base[i] = int(pid)
else:
    for i, (pid, p) in tqdm(enumerate(sim_list), total=N_base, desc="Loading sims", unit="file"):
        feat = load_pickle_feature(p, KEYS_TO_USE, EACH_LEN)
        X_base[i] = feat
        y_base[i] = float(id_to_target[pid])
        ids_base[i] = int(pid)

# ---------------------
# Split base simulations → 80/10/10 (no leakage)
# ---------------------
X_trainval_base, X_test_base, y_trainval_base, y_test_base = train_test_split(
    X_base, y_base, test_size=TEST_SIZE, random_state=SEED
)
val_frac_of_trainval = VAL_SIZE / (1.0 - TEST_SIZE)
X_train_base, X_val_base, y_train_base, y_val_base = train_test_split(
    X_trainval_base, y_trainval_base, test_size=val_frac_of_trainval, random_state=SEED
)

print(f"Base split sizes → train: {len(y_train_base)}, val: {len(y_val_base)}, test: {len(y_test_base)}")

# ---------------------
# Build pairs inside each split (CONCAT inputs, raw Δy target)
# ---------------------
rng = np.random.default_rng(SEED)

def make_pairs_concat(X: np.ndarray, y: np.ndarray,
                      pairs_per_item: int = PAIRS_PER_ITEM,
                      include_both: bool = INCLUDE_BOTH_DIRECTIONS,
                      rng: np.random.Generator = rng) -> Tuple[np.ndarray, np.ndarray]:
    """
    Returns:
      Xc: [M, 2*D] where = concat(x_i, x_j)
      yp: [M] with yp = y_i - y_j
    """
    X = np.asarray(X, dtype=np.float32)
    y = np.asarray(y, dtype=np.float32).reshape(-1)
    N, D = X.shape
    if N < 2:
        raise ValueError("Need at least 2 samples to form pairs.")

    max_pairs = N * pairs_per_item * (2 if include_both else 1)
    Xc = np.empty((max_pairs, 2 * D), dtype=np.float32)
    yp = np.empty(max_pairs, dtype=np.float32)
    used = 0

    indices = np.arange(N)
    for i in range(N):
        cand = indices[indices != i]
        if cand.size == 0:
            continue
        partners = cand if pairs_per_item >= cand.size else rng.choice(cand, size=pairs_per_item, replace=False)

        for j in partners:
            # (x_i ; x_j)
            Xc[used, :D] = X[i]
            Xc[used, D:] = X[j]
            yp[used] = y[i] - y[j]
            used += 1

            if include_both:
                # (x_j ; x_i)
                Xc[used, :D] = X[j]
                Xc[used, D:] = X[i]
                yp[used] = y[j] - y[i]
                used += 1

    return Xc[:used], yp[:used]

X_train_concat, y_train_pairs = make_pairs_concat(X_train_base, y_train_base)
X_val_concat,   y_val_pairs   = make_pairs_concat(X_val_base,   y_val_base)
X_test_concat,  y_test_pairs  = make_pairs_concat(X_test_base,  y_test_base)

print(f"Pair sizes → train: {len(y_train_pairs)}, val: {len(y_val_pairs)}, test: {len(y_test_pairs)}")

# ---------------------
# STANDARDIZE AFTER PAIRING (fit on TRAIN only)
# ---------------------
scaler_X = StandardScaler()  # mean/std across features of the 808-dim vector
X_train_scaled = scaler_X.fit_transform(X_train_concat)
X_val_scaled   = scaler_X.transform(X_val_concat)
X_test_scaled  = scaler_X.transform(X_test_concat)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train_pairs.reshape(-1, 1)).astype(np.float32).ravel()
y_val_scaled   = scaler_y.transform(y_val_pairs.reshape(-1, 1)).astype(np.float32).ravel()
# keep raw test target for metrics; model preds will be inverse-transformed later
y_test_raw     = y_test_pairs.astype(np.float32).reshape(-1)

# Build (808,1) inputs for the ANN
X_train_v21 = X_train_scaled.astype(np.float32)[..., None]   # (M, 808, 1)
X_val_v21   = X_val_scaled.astype(np.float32)[..., None]
X_test_v21  = X_test_scaled.astype(np.float32)[..., None]

print("Input concat vector shape (train):", X_train_v21.shape)
print("y_train (scaled) shape:", y_train_scaled.shape)

# ---------------------
# tf.data pipelines
# ---------------------
train_ds = (tf.data.Dataset.from_tensor_slices((X_train_v21, y_train_scaled))
            .shuffle(8192, seed=SEED, reshuffle_each_iteration=True).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE))

val_ds = (tf.data.Dataset.from_tensor_slices((X_val_v21, y_val_scaled)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE))

# ---------------------
# Train ANN (same model; just pass new input length)
# ---------------------
# >>> Your build_FDnirsANN_model must accept (input_len, lr, loss, etc.) and output a scalar <<<
model = build_FDnirsANN_model(D_INPUT, loss='mse')

callbacks = [
    keras.callbacks.ModelCheckpoint(BEST_MODEL, monitor='val_mae', mode='min',
                                    save_best_only=True, verbose=1),
    keras.callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.5, patience=10,
                                      min_lr=1e-6, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_mae', mode='min',
                                  patience=20, restore_best_weights=True, verbose=1),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

# Ensure the best version is saved
model.save(BEST_MODEL)

# ---------------------
# Evaluate on TEST pairs
#  - Model outputs normalized Δy; invert to RAW units for metrics/plots
# ---------------------
best = keras.models.load_model(BEST_MODEL, compile=False)
pred_test_scaled = best.predict(X_test_v21, batch_size=BATCH_SIZE, verbose=0).ravel().astype(np.float64)
pred_test_raw = scaler_y.inverse_transform(pred_test_scaled.reshape(-1, 1)).ravel()

mae  = mean_absolute_error(y_test_raw, pred_test_raw)
rmse = math.sqrt(mean_squared_error(y_test_raw, pred_test_raw))
r2   = r2_score(y_test_raw, pred_test_raw)

print("\n=== TEST METRICS on pairwise ΔHHB2 (concat 808×1; de-normalized) ===")
print(f"MAE : {mae:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"R^2 : {r2:.6f}")
print(f"Saved best model → {BEST_MODEL}")

# ---------------------
# Plot GT ΔHHB2 vs Pred ΔHHB2 (RAW units)
# ---------------------
plt.figure(figsize=(5, 4.5), dpi=160)
plt.scatter(y_test_raw, pred_test_raw, s=14, alpha=0.6, edgecolors='none')

lo = float(min(np.min(y_test_raw), np.min(pred_test_raw)))
hi = float(max(np.max(y_test_raw), np.max(pred_test_raw)))
if not np.isfinite(lo) or not np.isfinite(hi) or lo == hi:
    lo, hi = -1.0, 1.0

plt.plot([lo, hi], [lo, hi], 'k--', lw=1.2, alpha=0.8, label='y = x')

if np.std(y_test_raw) > 0:
    a, b = np.polyfit(y_test_raw, pred_test_raw, 1)
    xx = np.linspace(lo, hi, 200)
    plt.plot(xx, a * xx + b, lw=2, label=f'y = {a:.3f}x + {b:.3f}')

mse  = mean_squared_error(y_test_raw, pred_test_raw)
mare = np.mean(np.abs((pred_test_raw - y_test_raw) / np.clip(np.abs(y_test_raw), 1e-8, None))) * 100.0

plt.xlabel("GT ΔHHB2 (y1 - y2)")
plt.ylabel("Pred ΔHHB2 (ŷ1 - ŷ2)")
plt.title(f"Pairwise Test (Concat 808×1): R² = {r2:.3f}, MAE = {mae:.3f}, RMSE = {rmse:.3f}")

txt = f"MSE = {mse:.2e}\nMARE = {mare:.2f}%"
plt.text(0.02, 0.98, txt,
         transform=plt.gca().transAxes, va='top', ha='left',
         color='#9c2a2a', fontsize=11, fontweight='bold')
plt.legend(loc='lower right', frameon=False)
plt.tight_layout()
plt.show()
# Out:
# Found 3500 simulations with GT.
# Loading sims:   0%|          | 0/3500 [00:00<?, ?file/s]
# Base split sizes → train: 2800, val: 350, test: 350
# Pair sizes → train: 112000, val: 14000, test: 14000
# Input concat vector shape (train): (112000, 808, 1)
# y_train (scaled) shape: (112000,)
# Epoch 1/200
# 1731/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9400 - mae: 0.7874
# Epoch 1: val_mae improved from inf to 0.68313, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 26s 9ms/step - loss: 0.9387 - mae: 0.7868 - val_loss: 0.7127 - val_mae: 0.6831 - learning_rate: 3.0000e-04
# Epoch 2/200
# 1732/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6169 - mae: 0.6325
# Epoch 2: val_mae improved from 0.68313 to 0.66528, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.6167 - mae: 0.6324 - val_loss: 0.6767 - val_mae: 0.6653 - learning_rate: 3.0000e-04
# Epoch 3/200
# 1735/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5378 - mae: 0.5891
# Epoch 3: val_mae improved from 0.66528 to 0.61367, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.5377 - mae: 0.5890 - val_loss: 0.5752 - val_mae: 0.6137 - learning_rate: 3.0000e-04
# Epoch 4/200
# 1734/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4943 - mae: 0.5625
# Epoch 4: val_mae did not improve from 0.61367
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4942 - mae: 0.5625 - val_loss: 0.5886 - val_mae: 0.6213 - learning_rate: 3.0000e-04
# Epoch 5/200
# 1747/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4524 - mae: 0.5374
# Epoch 5: val_mae improved from 0.61367 to 0.57455, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4524 - mae: 0.5374 - val_loss: 0.5115 - val_mae: 0.5745 - learning_rate: 3.0000e-04
# Epoch 6/200
# 1749/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4329 - mae: 0.5239
# Epoch 6: val_mae improved from 0.57455 to 0.55960, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4329 - mae: 0.5239 - val_loss: 0.4830 - val_mae: 0.5596 - learning_rate: 3.0000e-04
# Epoch 7/200
# 1745/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4160 - mae: 0.5138
# Epoch 7: val_mae did not improve from 0.55960
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4160 - mae: 0.5138 - val_loss: 0.5017 - val_mae: 0.5678 - learning_rate: 3.0000e-04
# Epoch 8/200
# 1741/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4030 - mae: 0.5051
# Epoch 8: val_mae did not improve from 0.55960
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.4030 - mae: 0.5051 - val_loss: 0.5048 - val_mae: 0.5748 - learning_rate: 3.0000e-04
# Epoch 9/200
# 1730/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3917 - mae: 0.4970
# Epoch 9: val_mae improved from 0.55960 to 0.55543, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3917 - mae: 0.4970 - val_loss: 0.4758 - val_mae: 0.5554 - learning_rate: 3.0000e-04
# Epoch 10/200
# 1742/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3796 - mae: 0.4901
# Epoch 10: val_mae did not improve from 0.55543
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3796 - mae: 0.4901 - val_loss: 0.4944 - val_mae: 0.5647 - learning_rate: 3.0000e-04
# Epoch 11/200
# 1736/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3695 - mae: 0.4832
# Epoch 11: val_mae improved from 0.55543 to 0.55321, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3695 - mae: 0.4832 - val_loss: 0.4750 - val_mae: 0.5532 - learning_rate: 3.0000e-04
# Epoch 12/200
# 1735/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3649 - mae: 0.4789
# Epoch 12: val_mae improved from 0.55321 to 0.52546, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3649 - mae: 0.4789 - val_loss: 0.4293 - val_mae: 0.5255 - learning_rate: 3.0000e-04
# Epoch 13/200
# 1735/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3501 - mae: 0.4689
# Epoch 13: val_mae did not improve from 0.52546
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3501 - mae: 0.4689 - val_loss: 0.4447 - val_mae: 0.5366 - learning_rate: 3.0000e-04
# Epoch 14/200
# 1745/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3465 - mae: 0.4666
# Epoch 14: val_mae did not improve from 0.52546
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3465 - mae: 0.4666 - val_loss: 0.4357 - val_mae: 0.5312 - learning_rate: 3.0000e-04
# Epoch 15/200
# 1745/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3340 - mae: 0.4570
# Epoch 15: val_mae did not improve from 0.52546
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3341 - mae: 0.4570 - val_loss: 0.4781 - val_mae: 0.5536 - learning_rate: 3.0000e-04
# Epoch 16/200
# 1734/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3296 - mae: 0.4541
# Epoch 16: val_mae did not improve from 0.52546
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3296 - mae: 0.4541 - val_loss: 0.4863 - val_mae: 0.5569 - learning_rate: 3.0000e-04
# Epoch 17/200
# 1734/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3230 - mae: 0.4493
# Epoch 17: val_mae improved from 0.52546 to 0.52479, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3230 - mae: 0.4493 - val_loss: 0.4241 - val_mae: 0.5248 - learning_rate: 3.0000e-04
# Epoch 18/200
# 1744/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3146 - mae: 0.4434
# Epoch 18: val_mae did not improve from 0.52479
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3146 - mae: 0.4435 - val_loss: 0.4485 - val_mae: 0.5416 - learning_rate: 3.0000e-04
# Epoch 19/200
# 1739/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3081 - mae: 0.4375
# Epoch 19: val_mae did not improve from 0.52479
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3082 - mae: 0.4375 - val_loss: 0.4529 - val_mae: 0.5400 - learning_rate: 3.0000e-04
# Epoch 20/200
# 1744/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3015 - mae: 0.4327
# Epoch 20: val_mae did not improve from 0.52479
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.3015 - mae: 0.4327 - val_loss: 0.4612 - val_mae: 0.5460 - learning_rate: 3.0000e-04
# Epoch 21/200
# 1736/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2997 - mae: 0.4310
# Epoch 21: val_mae did not improve from 0.52479
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2997 - mae: 0.4310 - val_loss: 0.4550 - val_mae: 0.5407 - learning_rate: 3.0000e-04
# Epoch 22/200
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2899 - mae: 0.4235
# Epoch 22: val_mae did not improve from 0.52479
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2899 - mae: 0.4235 - val_loss: 0.4416 - val_mae: 0.5292 - learning_rate: 3.0000e-04
# Epoch 23/200
# 1738/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2831 - mae: 0.4177
# Epoch 23: val_mae did not improve from 0.52479
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2831 - mae: 0.4177 - val_loss: 0.4546 - val_mae: 0.5406 - learning_rate: 3.0000e-04
# Epoch 24/200
# 1730/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2781 - mae: 0.4146
# Epoch 24: val_mae improved from 0.52479 to 0.52195, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2781 - mae: 0.4146 - val_loss: 0.4210 - val_mae: 0.5220 - learning_rate: 3.0000e-04
# Epoch 25/200
# 1735/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2754 - mae: 0.4112
# Epoch 25: val_mae did not improve from 0.52195
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2754 - mae: 0.4112 - val_loss: 0.4559 - val_mae: 0.5444 - learning_rate: 3.0000e-04
# Epoch 26/200
# 1741/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2648 - mae: 0.4032
# Epoch 26: val_mae did not improve from 0.52195
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2648 - mae: 0.4032 - val_loss: 0.4632 - val_mae: 0.5391 - learning_rate: 3.0000e-04
# Epoch 27/200
# 1730/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2616 - mae: 0.4014
# Epoch 27: val_mae did not improve from 0.52195
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2616 - mae: 0.4014 - val_loss: 0.4783 - val_mae: 0.5514 - learning_rate: 3.0000e-04
# Epoch 28/200
# 1740/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2610 - mae: 0.3999
# Epoch 28: val_mae did not improve from 0.52195
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2610 - mae: 0.3999 - val_loss: 0.4331 - val_mae: 0.5272 - learning_rate: 3.0000e-04
# Epoch 29/200
# 1737/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2538 - mae: 0.3941
# Epoch 29: val_mae did not improve from 0.52195
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2538 - mae: 0.3941 - val_loss: 0.4360 - val_mae: 0.5252 - learning_rate: 3.0000e-04
# Epoch 30/200
# 1739/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2427 - mae: 0.3846
# Epoch 30: val_mae improved from 0.52195 to 0.51385, saving model to best_pair_ann_808x1.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2427 - mae: 0.3847 - val_loss: 0.4138 - val_mae: 0.5139 - learning_rate: 3.0000e-04
# Epoch 31/200
# 1731/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2460 - mae: 0.3869
# Epoch 31: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2460 - mae: 0.3869 - val_loss: 0.4519 - val_mae: 0.5384 - learning_rate: 3.0000e-04
# Epoch 32/200
# 1737/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2365 - mae: 0.3795
# Epoch 32: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2366 - mae: 0.3796 - val_loss: 0.4452 - val_mae: 0.5350 - learning_rate: 3.0000e-04
# Epoch 33/200
# 1732/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2320 - mae: 0.3754
# Epoch 33: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2321 - mae: 0.3755 - val_loss: 0.4554 - val_mae: 0.5382 - learning_rate: 3.0000e-04
# Epoch 34/200
# 1739/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2329 - mae: 0.3752
# Epoch 34: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2329 - mae: 0.3752 - val_loss: 0.4254 - val_mae: 0.5244 - learning_rate: 3.0000e-04
# Epoch 35/200
# 1732/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2282 - mae: 0.3711
# Epoch 35: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2282 - mae: 0.3711 - val_loss: 0.4518 - val_mae: 0.5332 - learning_rate: 3.0000e-04
# Epoch 36/200
# 1732/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2283 - mae: 0.3706
# Epoch 36: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2283 - mae: 0.3706 - val_loss: 0.4790 - val_mae: 0.5519 - learning_rate: 3.0000e-04
# Epoch 37/200
# 1731/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2172 - mae: 0.3616
# Epoch 37: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2173 - mae: 0.3616 - val_loss: 0.4385 - val_mae: 0.5271 - learning_rate: 3.0000e-04
# Epoch 38/200
# 1730/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2178 - mae: 0.3612
# Epoch 38: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2178 - mae: 0.3612 - val_loss: 0.4497 - val_mae: 0.5323 - learning_rate: 3.0000e-04
# Epoch 39/200
# 1749/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2100 - mae: 0.3555
# Epoch 39: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2100 - mae: 0.3555 - val_loss: 0.4578 - val_mae: 0.5394 - learning_rate: 3.0000e-04
# Epoch 40/200
# 1729/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2067 - mae: 0.3515
# Epoch 40: val_mae did not improve from 0.51385
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.2068 - mae: 0.3516 - val_loss: 0.4544 - val_mae: 0.5361 - learning_rate: 3.0000e-04
# Epoch 41/200
# 1740/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1796 - mae: 0.3275
# Epoch 41: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1795 - mae: 0.3274 - val_loss: 0.4339 - val_mae: 0.5220 - learning_rate: 1.5000e-04
# Epoch 42/200
# 1745/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1674 - mae: 0.3149
# Epoch 42: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1674 - mae: 0.3149 - val_loss: 0.4215 - val_mae: 0.5165 - learning_rate: 1.5000e-04
# Epoch 43/200
# 1744/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1653 - mae: 0.3123
# Epoch 43: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1653 - mae: 0.3123 - val_loss: 0.4311 - val_mae: 0.5193 - learning_rate: 1.5000e-04
# Epoch 44/200
# 1740/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1591 - mae: 0.3060
# Epoch 44: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1591 - mae: 0.3060 - val_loss: 0.4300 - val_mae: 0.5192 - learning_rate: 1.5000e-04
# Epoch 45/200
# 1747/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1573 - mae: 0.3041
# Epoch 45: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1573 - mae: 0.3041 - val_loss: 0.4625 - val_mae: 0.5412 - learning_rate: 1.5000e-04
# Epoch 46/200
# 1735/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1542 - mae: 0.3013
# Epoch 46: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1542 - mae: 0.3013 - val_loss: 0.4245 - val_mae: 0.5200 - learning_rate: 1.5000e-04
# Epoch 47/200
# 1741/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1543 - mae: 0.2997
# Epoch 47: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1543 - mae: 0.2997 - val_loss: 0.4602 - val_mae: 0.5379 - learning_rate: 1.5000e-04
# Epoch 48/200
# 1738/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1486 - mae: 0.2955
# Epoch 48: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1486 - mae: 0.2955 - val_loss: 0.4439 - val_mae: 0.5274 - learning_rate: 1.5000e-04
# Epoch 49/200
# 1739/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1463 - mae: 0.2924
# Epoch 49: val_mae did not improve from 0.51385
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1463 - mae: 0.2924 - val_loss: 0.4360 - val_mae: 0.5232 - learning_rate: 1.5000e-04
# Epoch 50/200
# 1746/1750 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1430 - mae: 0.2891
# Epoch 50: val_mae did not improve from 0.51385
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 1750/1750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - loss: 0.1430 - mae: 0.2891 - val_loss: 0.4472 - val_mae: 0.5323 - learning_rate: 1.5000e-04
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 30.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# === TEST METRICS on pairwise ΔHHB2 (concat 808×1; de-normalized) ===
# MAE : 3.241788
# RMSE: 4.060360
# R^2 : 0.528742
# Saved best model → best_pair_ann_808x1.h5
